# %% [markdown]
# # Classification models
# - Train BERT models to classify each topic. Start off as binary classification and not multiclass/multilabel
# - Training locally on a CPU, therefore these models are a first-pass experimental stage
# - Models are used to predict on all the data and then manually inspect of the predicted topics make sense

# %%
labelled_data_path = "../Data/labelling/news_and_twitter_labelling_1.xlsx"

# %% [markdown]
# ## Prep the labels for training

# %%
import os 
import pandas as pd 
import numpy as np
import math
import pickle

# %%
# labelled data 
df = pd.read_excel(labelled_data_path, sheet_name="guardian", index_col=0)
# all the data with all the fields 
df_all = pd.read_csv("resources/df_guardian_lem_nov14.csv", index_col=0)

# %% [markdown]
# Count the number of labelled exampled in each category

# %%
categories = [
    'economy', 'case_reporting', 'treatments_vaccines',
    'education', 'travel_lockdown', 'healthcare',
    'other', 'politics', 'environment', 'social_issues'
]

# %%
total_labelled = 0
for category in categories: 
    df_category = df.dropna(subset=[category])
    print("Number of examples for {}: {}".format(category, len(df_category)))
    total_labelled += len(df_category)
print(total_labelled)
# Out:
# Number of examples for economy: 211
# Number of examples for case_reporting: 109
# Number of examples for treatments_vaccines: 32
# Number of examples for education: 51
# Number of examples for travel_lockdown: 182
# Number of examples for healthcare: 84
# Number of examples for other: 139
# Number of examples for politics: 105
# Number of examples for environment: 21
# Number of examples for social_issues: 153
# 1087

# %% [markdown]
# ### Create training and val data for each
# - also include testing data from the full dataset
# - take all the positive examples for that category
# - for the negative examples, take as many or up to 2 times as many examples from other categories

# %%
def get_train_data(category, prop_negative=1, test_size=500):
    df_positive = df.dropna(subset=[category])[['webPublicationDate', 'title_subtitle'] + [category]]
    df_negative = df[df[category].isna()].sample(n = math.floor(prop_negative * len(df_positive)))[['webPublicationDate', 'title_subtitle'] + [category]]
    df_negative = df_negative.fillna("no")
    df_category = pd.concat([df_positive, df_negative]).sample(frac=1)
    # finally replace yes and no with 1 and 0 
    df_category[category] = df_category[category].replace({"yes": 1, 'no':0})
    # match to the full data to get all the columns 
    df_category = df_category[[category]].join(df_all, how="inner")
    # get test data 
    df_test = df_all[~df_all.index.isin(df_category.index)]#.sample(test_size)
    return df_category, df_test

# %%
prop_negative = 1
test_size = 1000
dfs_train, dfs_test = {}, {}
for category in categories: 
    df_train, df_test =get_train_data(category, prop_negative, test_size)
    dfs_train[category] = df_train
    dfs_test[category] = df_test

# %% [markdown]
# # Models

# %%
from sklearn.model_selection import train_test_split

from tensorflow import keras

from transformers import TFBertModel,  BertConfig, BertTokenizerFast
from tensorflow.keras.layers import Input, Dropout, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.initializers import TruncatedNormal
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.metrics import BinaryAccuracy
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# ### Set up the model

# %%
def get_model(max_length):
    model_name = 'bert-base-uncased'
    config = BertConfig.from_pretrained(model_name)
    config.output_hidden_states = False
    # Load tokenizer
    tokenizer = BertTokenizerFast.from_pretrained(pretrained_model_name_or_path = model_name, config = config)
    # Load the Transformers model
    transformer_model = TFBertModel.from_pretrained(model_name, config = config)
    
    bert = transformer_model.layers[0]
    input_ids = Input(shape=(max_length,), name='input_ids', dtype='int32')
    inputs = {'input_ids': input_ids}
    bert_model = bert(inputs)[1]
    dropout = Dropout(config.hidden_dropout_prob, name='pooled_output')
    pooled_output = dropout(bert_model, training=False)

    issue = Dense(
        activation='softmax',
        units=2, 
        kernel_initializer=TruncatedNormal(stddev=config.initializer_range), 
        name='issue')(pooled_output)
    outputs = {'issue': issue}

    model = Model(inputs=inputs, outputs=outputs, name='BERT')

    model.summary()
    
    # Set an optimizer
    optimizer = Adam(
        learning_rate=5e-05,
        epsilon=1e-08,
        decay=0.01,
        clipnorm=1.0)
    
    # Set loss and metrics
    loss = {'issue': BinaryCrossentropy(from_logits = True)}
    metric = {'issue': BinaryAccuracy('accuracy')}
    
    # Compile the model
    model.compile(
        optimizer = optimizer,
        loss = loss, 
        metrics = metric)
    
    return model, tokenizer

# %%
def transform_train_data(data, label, field, max_length):
    # Ready output data for the model
    y = to_categorical(data[label])
    
    # Tokenize the input
    x = tokenizer(
        text=data[field].to_list(),
        add_special_tokens=True,
        max_length=max_length,
        truncation=True,
        padding=True, 
        return_tensors='tf',
        return_token_type_ids = False,
        return_attention_mask = False,
        verbose = True)
    return x, y

# %%
def fit_model(model, data, label, field, max_length, batch_size=64, epochs=5):
    x, y = transform_train_data(data, label, field, max_length)
    # Fit the model
    history = model.fit(
        x={'input_ids': x['input_ids']},
        y={'issue': y},
        validation_split=0.2,
        batch_size=batch_size,
        epochs=epochs,
    )
    return history, model

# %% [markdown]
# ### set up evaluation and prediction

# %%
def evaluate(data_val, label, field, max_length, model):
    val_y = to_categorical(data_val[label])
    val_x = tokenizer(
        text=data_val[field].to_list(),
        add_special_tokens=True,
        max_length=max_length,
        truncation=True,
        padding=True, 
        return_tensors='tf',
        return_token_type_ids = False,
        return_attention_mask = False,
        verbose = True)
    # Run evaluation
    model_eval = model.evaluate(
        x={'input_ids': val_x['input_ids'], }
    )
    return model_eval

# %%
def predict(data_test, field, max_length, model, tokenizer):
    test_x = tokenizer(
        text=data_test[field].to_list(),
        add_special_tokens=True,
        max_length=max_length,
        truncation=True,
        padding=True, 
        return_tensors='tf',
        return_token_type_ids = False,
        return_attention_mask = False,
        verbose = True)
    preds = model.predict(test_x['input_ids'])
    
    preds_df = pd.DataFrame(preds['issue'])
    preds_df.columns = ['pred_0', 'pred_1']
    preds_df.index = data_test.index
    preds_df = preds_df.join(df, how="inner")
    return preds_df

# %% [markdown]
# ## --> Train and predict

# %% [markdown]
# ### economy

# %%
label = "economy"
field = "title_subtitle_bow"
# Split into train and val
data, data_val = train_test_split(dfs_train['economy'], test_size = 0.2, stratify = dfs_train['economy'][[label]])
max_length = 100

# %%
model, tokenizer = get_model(max_length = max_length)
history, model = fit_model(model, data, label, field, max_length)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing TFBertModel: ['mlm___cls', 'nsp___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Model: "BERT"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_ids (InputLayer)       [(None, 100)]             0
# _________________________________________________________________
# bert (TFBertMainLayer)       ((None, 100, 768), (None, 109482240
# _________________________________________________________________
# pooled_output (Dropout)      (None, 768)               0
# _________________________________________________________________
# issue (Dense)                (None, 2)                 1538
# =================================================================
# Total params: 109,483,778
# Trainable params: 109,483,778
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 5/5 [==============================] - 79s 16s/step - loss: 0.7211 - accuracy: 0.5428 - val_loss: 0.6930 - val_accuracy: 0.6765
# Epoch 2/5
# 5/5 [==============================] - 83s 17s/step - loss: 0.7017 - accuracy: 0.6320 - val_loss: 0.6826 - val_accuracy: 0.6912
# Epoch 3/5
# 5/5 [==============================] - 85s 17s/step - loss: 0.6554 - accuracy: 0.7807 - val_loss: 0.6133 - val_accuracy: 0.8529
# Epoch 4/5
# 5/5 [==============================] - 83s 17s/step - loss: 0.5847 - accuracy: 0.9108 - val_loss: 0.6040 - val_accuracy: 0.8088
# Epoch 5/5
# 5/5 [==============================] - 86s 17s/step - loss: 0.5615 - accuracy: 0.9257 - val_loss: 0.5560 - val_accuracy: 0.9118

# %%
# save the model 
model.save('models/model_economy')
# Out:
# WARNING:tensorflow:From /Users/dea/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /Users/dea/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: models/model_economy/assets

# %%
# load the model
reconstructed_model = keras.models.load_model("models/model_economy")

# %%
preds_df = predict(data_test=dfs_test['economy'], field=field, max_length=max_length, model=reconstructed_model, tokenizer=tokenizer)

# %%
preds_df.nlargest(30, "pred_1")['title_subtitle'].tolist()
# Out:
# ["Coronavirus profiteers' condemned as polluters gain bailout billions.  Leading figures condemn bailouts backing sectors that disregard green economy goals in recovery after pandemic ",
#  'Covid-19 could cause permanent shift towards home working. Tech firms will benefit, but some companies could find employees don’t want to return to the office',
#  'Will investing in our newfound sense of community bring returns?. Local firms offering high interest rates are selling a better way to rebuild the UK after Covid. But there are risks',
#  'Billion-dollar wildlife industry in Vietnam under assault as law drafted to halt trading. Move aimed at street markets, online traders and farms with links to illegal wildlife trading',
#  'Africa leads calls for debt relief in face of coronavirus crisis. IMF and World Bank back moves to put pressure on creditors in bid to strengthen health systems',
#  "Mike Ashley's Frasers Group buys fitness chain DW Sports. Frasers Group to pay initial £37m for ‘certain assets’, which excludes DW business name",
#  'Goldman Sachs closes Marcus account to new UK savers. Deluge of deposits during coronavirus crisis pushed it close to regulatory limits',
#  'Covid-19 economic rescue plans must be green, say environmentalists.  Campaigners urge governments to tie any bailouts to aviation and cruise industries to requirements for climate action ',
#  'UK homebuyers told to act fast to beat stamp duty holiday deadline. Covid restrictions and high demand for mortgages create delays in property process',
#  "Future market for Covid vaccines 'could be worth more than $10bn a year'. Analysts estimate revenue generated, assuming an annual jab at an average price of $20",
#  "Absolutely fanciful': Boris Johnson's new deal not Rooseveltian, say critics. The PM wants to be put on the same pedestal as Franklin D Roosevelt as he unveils £5bn capital projects",
#  'Hoseasons and Cottages.com owner changes refund policy after complaints. Watchdog says it has received 4,500 complaints about holiday rental firms in Covid-19 crisis',
#  "Trump's bid to calm crisis simply caused more financial chaos. It is not just the obvious candidates whose shares have fallen – there is now a fear of financial contagion",
#  'UK travel insurers stopping policy sales over coronavirus. Which? calls for urgent action by government, insurance firms and travel sector',
#  'Pharmacies in England pause online flu jab bookings as demand soars. Boots, LloydsPharmacy and Well Pharmacy report unprecedented take-up and many chemists run out of stock',
#  'Greater Manchester leaders and No 10 at odds over tier 3 lockdown plans.  Andy Burnham denies meeting has been arranged to end deadlock over financial aid package',
#  'Eurostar backtracks over coronavirus refunds after complaints. Customers say they were denied cancellation repayments and pushed to accept unusable vouchers',
#  'Shopper numbers jump 31% as lockdown in England relaxed. Long queues outside Ikea as retailers including car showrooms and markets reopen',
#  'Shopping centre owner Hammerson says rent takings down two-thirds. Retail landlord deluged with deferral requests amid coronavirus lockdown',
#  'Flexible working will be norm after lockdown, say Barclays and WPP bosses. Crowded office buildings ‘may be a thing of the past’ as staff safety prioritised after Covid-19 crisis',
#  "This crisis calls for massive government intervention: here's how to do it | Emmanuel Saez and Gabriel Zucman. The state should step in as payer of last resort for businesses facing shutdown as coronavirus hits them hard, say economics professors Emmanuel Saez and Gabriel Zucman",
#  'EU turns up pressure on Matt Hancock over Covid-19 PPE scheme. Brussels says UK was briefed on bulk-buying plan and given ‘ample opportunity’ to join',
#  'Incoherence at the heart of government is making a calamitous slump worse. The chancellor is reluctant to help firms hampered by the two-metre rule. Johnson disagrees. And everyone is left floundering',
#  "Sainsbury's revives bicycle deliveries in central London.  Chop Chop service repurposes closed Blackfriars store to assist customers in lockdown",
#  "Johnson's coronavirus workplace guidance confused, warn unions. GMB says employers need more support to ensure safe return on 1 August ",
#  'How a decade of privatisation and cuts exposed England to coronavirus. Government reliance on private contractors follows dramatic changes to local councils and public services',
#  'Chocolate sales soar as UK shoppers comfort eat at home amid Covid. Annual spend up £50m driven by multipacks and ‘sharing bars’, but smaller bars decline',
#  'UK supermarkets urge shoppers not to panic over lockdown fears. Bosses of major grocery chains caution against stockpiling as Asda brings in 1,000 safety marshals',
#  "Sainsbury's bans couples from stores but eases buying limits. Retailer introduces one adult per household rule as stock returns to normal levels",
#  'JD Wetherspoon plans to reopen pubs in June. After Tim Martin’s scepticism over lockdown, chief executive delivers upbeat message to investors']

# %%
preds_df.to_csv("models/preds_economy.csv")

# %% [markdown]
# ### case_reporting

# %%
label = "case_reporting"
field = "title_subtitle_bow"
# Split into train and val
data, data_val = train_test_split(dfs_train[label], test_size = 0.2, stratify = dfs_train[label][[label]])
max_length = 100

# %%
model, tokenizer = get_model(max_length = max_length)
history, model = fit_model(model, data, label, field, max_length)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing TFBertModel: ['nsp___cls', 'mlm___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Model: "BERT"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_ids (InputLayer)       [(None, 100)]             0
# _________________________________________________________________
# bert (TFBertMainLayer)       ((None, 100, 768), (None, 109482240
# _________________________________________________________________
# pooled_output (Dropout)      (None, 768)               0
# _________________________________________________________________
# issue (Dense)                (None, 2)                 1538
# =================================================================
# Total params: 109,483,778
# Trainable params: 109,483,778
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# WARNING:tensorflow:Model was constructed with shape (None, 100) for input Tensor("input_ids:0", shape=(None, 100), dtype=int32), but it was called on an input with incompatible shape (None, 62).
# WARNING:tensorflow:Model was constructed with shape (None, 100) for input Tensor("input_ids:0", shape=(None, 100), dtype=int32), but it was called on an input with incompatible shape (None, 62).
# 3/3 [==============================] - ETA: 0s - loss: 0.7335 - accuracy: 0.4029WARNING:tensorflow:Model was constructed with shape (None, 100) for input Tensor("input_ids:0", shape=(None, 100), dtype=int32), but it was called on an input with incompatible shape (None, 62).
# 3/3 [==============================] - 21s 7s/step - loss: 0.7335 - accuracy: 0.4029 - val_loss: 0.7231 - val_accuracy: 0.5143
# Epoch 2/5
# 3/3 [==============================] - 20s 7s/step - loss: 0.7206 - accuracy: 0.4964 - val_loss: 0.7169 - val_accuracy: 0.5143
# Epoch 3/5
# 3/3 [==============================] - 20s 7s/step - loss: 0.7126 - accuracy: 0.4964 - val_loss: 0.7109 - val_accuracy: 0.5143
# Epoch 4/5
# 3/3 [==============================] - 18s 6s/step - loss: 0.6910 - accuracy: 0.6043 - val_loss: 0.6767 - val_accuracy: 0.7143
# Epoch 5/5
# 3/3 [==============================] - 20s 7s/step - loss: 0.6485 - accuracy: 0.8777 - val_loss: 0.6397 - val_accuracy: 0.8571

# %%
# save the model 
model.save('models/model_{}'.format(label))
# Out:
# WARNING:tensorflow:From /Users/dea/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /Users/dea/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: models/model_case_reporting/assets

# %%
# load the model
reconstructed_model = keras.models.load_model('models/model_{}'.format(label))

# %%
preds_df = predict(data_test=dfs_test[label], field=field, max_length=max_length, model=reconstructed_model, tokenizer=tokenizer)

# %%
preds_df.nlargest(30, "pred_1")['title_subtitle'].tolist()
# Out:
# ['UK manufacturing shows hint of recovery after coronavirus. IHS Markit says worst of downturn is probably over after fall in factory output slows<br>',
#  'The coronavirus panic is turning the UK into a hostile environment for east Asians | Sam Phan. Stereotypes are spreading as quickly as the virus. On the bus, in the street, people have started treating us as if we’re infected, says student Sam Phan',
#  'Coronavirus: EU states enact tough measures to stem spread. Several states ban mass events and close schools, as infection and death rates fall in China',
#  'Britain wins rare praise for leading race to test life-saving Covid drugs. UK’s high infection rate and centralised NHS have enabled Recovery team to help victims across the world',
#  '‘We’ve learned how we need to act’: Spain braces for second wave of Covid. An increase in infections, particularly among younger age groups, is causing a spike centred on the area around Madrid',
#  'Coronavirus: is this the start of a second wave and is the UK prepared?. Cases of Covid-19 are rising here and across Europe as UK universities plan to reopen. What is the outlook for autumn?',
#  'UK scientists seek  mutant Covid samples from Danish mink farms. Tests will investigate whether virus evades antibodies from recovered patients and those in vaccine trials',
#  "Britain left off 'safe list' of countries free to holiday in Greece. UK fails to fit epidemiological profile demanded by Athens, which has kept Covid-19 in check<br>",
#  'Coronavirus bill has cost UK government £210bn, spending watchdog says. NAO forecast for costs of 190 pandemic measures over half year finds furlough outlay of £35.4bn so far most expensive',
#  'Covid-19: did the UK government prepare for the wrong kind of pandemic?. Britain’s highly rated disease preparation failed on coronavirus – possibly because ministers followed a plan for flu<br>',
#  "If it comes, it will overwhelm us': Malawi braces for coronavirus. Concern is growing that a woefully inadequate health system will leave Malawi unable to cope when Covid-19 arrives",
#  'UK scientists want to infect volunteers with Covid-19 in race to find vaccine. Trials could be speeded up by using risky strategy of deliberately introducing the virus ',
#  'Covid fears grow after reports of crowding among arrivals at UK airports. Passengers returning to UK in recent days report lack of quarantine information or checks on test and trace forms',
#  'Recovery trial for Covid-19 treatments: what we know so far. The biggest randomised controlled trial of drugs against Covid-19 in the world is already producing results',
#  "Future market for Covid vaccines 'could be worth more than $10bn a year'. Analysts estimate revenue generated, assuming an annual jab at an average price of $20",
#  'University of Liverpool confirms 87 Covid cases in week before start of term. Other campuses face outbreaks as Boris Johnson calls for universities to stay open',
#  "It's a disaster': Egypt's doctors plead for more PPE and testing. Medics increasingly at odds with government that is urging citizens to ‘coexist’ with Covid-19",
#  'UK care homes still denied Covid tests despite Hancock pledge,  officials warn. Bosses of adult services say relatives cannot make vital visits to elderly and other vulnerable residents ',
#  'UK adds France to Covid-19 14-day quarantine list. Travellers arriving from France after 4am on Saturday will need to quarantine for 14 days',
#  "Major' breakthrough in Covid-19 drug makes UK professors millionaires. Synairgen’s share price rises 540% on morning of news of successful drugs trial",
#  'Prince William and Kate speak of coronavirus impact on NHS staff. Duke and Duchess of Cambridge say daily stress of helping critically ill patients is not normal<br>',
#  "It’s a razor’s edge we’re walking': inside the race to develop a coronavirus vaccine. <strong>The long read</strong>: Around the world, more than 40 teams are working on a vaccine for Covid-19. We followed one doctor in the most urgent quest of his life",
#  'Coronavirus UK: BAME women suffer harder financial hit. Study also shows that psychological consequences are worse than for white women ',
#  'UK behind most European states in tackling coronavirus, says EU agency. Disease control centre delivers blow to Boris Johnson’s claims of successful strategy',
#  'Coronavirus: three more cases in UK amid fears over strain on NHS. Calls for doctors to be brought out of retirement if possible epidemic hits NHS workforce',
#  'UK hospitals to trial five new drugs in search for coronavirus treatment. Exclusive: thirty hospitals looking to sign up hundreds of patients to take part in studies',
#  'The northern lockdown represents government failure. There is a better way | Devi Sridhar. Had Britain devised clear, tough outbreak control measures, the latest Covid-19 restrictions wouldn’t have been necessary, says public health professor Devi Sridhar',
#  "Coronavirus vaccine trials could be done 'by mid-August'. UK taskforce comment comes amid mounting pressure to provide PPE to frontline workers",
#  'Covid-19 spilling out of hospitals and care homes, says UK expert. Prof Neil Ferguson tells Lords committee cases will remain steady until September<br>',
#  'Watchdog approves use of UK phone data to help fight coronavirus. Public bodies may need to collect more information to protect public health, says ICO']

# %%
preds_df.to_csv("models/preds_{}.csv".format(label))

# %% [markdown]
# ### treatments_vaccines

# %%
label = "treatments_vaccines"
field = "title_subtitle_bow"
# Split into train and val
data, data_val = train_test_split(dfs_train[label], test_size = 0.2, stratify = dfs_train[label][[label]])
max_length = 100

# %%
model, tokenizer = get_model(max_length = max_length)
history, model = fit_model(model, data, label, field, max_length)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing TFBertModel: ['nsp___cls', 'mlm___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Model: "BERT"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_ids (InputLayer)       [(None, 100)]             0
# _________________________________________________________________
# bert (TFBertMainLayer)       ((None, 100, 768), (None, 109482240
# _________________________________________________________________
# pooled_output (Dropout)      (None, 768)               0
# _________________________________________________________________
# issue (Dense)                (None, 2)                 1538
# =================================================================
# Total params: 109,483,778
# Trainable params: 109,483,778
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# WARNING:tensorflow:Model was constructed with shape (None, 100) for input Tensor("input_ids:0", shape=(None, 100), dtype=int32), but it was called on an input with incompatible shape (None, 60).
# WARNING:tensorflow:Model was constructed with shape (None, 100) for input Tensor("input_ids:0", shape=(None, 100), dtype=int32), but it was called on an input with incompatible shape (None, 60).
# 1/1 [==============================] - ETA: 0s - loss: 0.7204 - accuracy: 0.5250WARNING:tensorflow:Model was constructed with shape (None, 100) for input Tensor("input_ids:0", shape=(None, 100), dtype=int32), but it was called on an input with incompatible shape (None, 60).
# 1/1 [==============================] - 4s 4s/step - loss: 0.7204 - accuracy: 0.5250 - val_loss: 0.7204 - val_accuracy: 0.5455
# Epoch 2/5
# 1/1 [==============================] - 1s 834ms/step - loss: 0.7297 - accuracy: 0.4500 - val_loss: 0.7173 - val_accuracy: 0.6364
# Epoch 3/5
# 1/1 [==============================] - 1s 790ms/step - loss: 0.7117 - accuracy: 0.5500 - val_loss: 0.7149 - val_accuracy: 0.4545
# Epoch 4/5
# 1/1 [==============================] - 1s 750ms/step - loss: 0.7027 - accuracy: 0.5500 - val_loss: 0.7018 - val_accuracy: 0.5455
# Epoch 5/5
# 1/1 [==============================] - 1s 788ms/step - loss: 0.6643 - accuracy: 0.9250 - val_loss: 0.6784 - val_accuracy: 0.8182

# %%
# save the model 
model.save('models/model_{}'.format(label))
# Out:
# WARNING:tensorflow:From /Users/dea/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /Users/dea/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: models/model_treatments_vaccines/assets

# %%
# load the model
reconstructed_model = keras.models.load_model('models/model_{}'.format(label))

# %%
preds_df = predict(data_test=dfs_test[label], field=field, max_length=max_length, model=reconstructed_model, tokenizer=tokenizer)

# %%
preds_df.nlargest(30, "pred_1")['title_subtitle'].tolist()
# Out:
# ['Why does Covid-19 affect ethnic minorities so badly? It isn’t to do with biology | Zubaida Haque. All the evidence points to race inequality as an urgent aspect of the epidemic, but the government refuses to act, says Zubaida Haque of the Runnymede Trust',
#  'Why is South Korea beating coronavirus? Its citizens hold the state to account | Tae Hoon Kim. The widely lauded policy of testing, tracing and treating has its roots in Koreans’ expectation of high-quality public services, says geopolitical analyst Tae Hoon Kim',
#  "Coronavirus shows us it’s time to rethink everything. Let's start with education | George Monbiot. The pandemic is a tough lesson in the workings of the natural world – and proves how vital a knowledge of ecology really is, says Guardian columnist George Monbiot",
#  'Disunited nations of coronavirus: Inside the 7 August Guardian Weekly. Six months after the UK’s first reported case of Covid-19, we look at how the world is adapting to the new realities of life. <strong>To get the Guardian Weekly delivered to your home, click here</strong>',
#  "Counting the human cost of Covid-19: 'Numbers tell a story words can't'. The Guardian’s data journalists in the UK, US and Australia explain how they have shone a light on the statistical narrative behind the pandemic, and what they have helped to reveal "]

# %%
preds_df.to_csv("models/preds_{}.csv".format(label))

# %% [markdown]
# ### education

# %%
label = "education"
field = "title_subtitle_bow"
# Split into train and val
data, data_val = train_test_split(dfs_train[label], test_size = 0.2, stratify = dfs_train[label][[label]])
max_length = 100

# %%
model, tokenizer = get_model(max_length = max_length)
history, model = fit_model(model, data, label, field, max_length)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing TFBertModel: ['mlm___cls', 'nsp___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Model: "BERT"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_ids (InputLayer)       [(None, 100)]             0
# _________________________________________________________________
# bert (TFBertMainLayer)       ((None, 100, 768), (None, 109482240
# _________________________________________________________________
# pooled_output (Dropout)      (None, 768)               0
# _________________________________________________________________
# issue (Dense)                (None, 2)                 1538
# =================================================================
# Total params: 109,483,778
# Trainable params: 109,483,778
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# WARNING:tensorflow:Model was constructed with shape (None, 100) for input Tensor("input_ids:0", shape=(None, 100), dtype=int32), but it was called on an input with incompatible shape (64, 69).
# WARNING:tensorflow:Model was constructed with shape (None, 100) for input Tensor("input_ids:0", shape=(None, 100), dtype=int32), but it was called on an input with incompatible shape (64, 69).
# 1/1 [==============================] - ETA: 0s - loss: 0.7239 - accuracy: 0.5312WARNING:tensorflow:Model was constructed with shape (None, 100) for input Tensor("input_ids:0", shape=(None, 100), dtype=int32), but it was called on an input with incompatible shape (None, 69).
# 1/1 [==============================] - 4s 4s/step - loss: 0.7239 - accuracy: 0.5312 - val_loss: 0.7592 - val_accuracy: 0.4118
# Epoch 2/5
# 1/1 [==============================] - 1s 1s/step - loss: 0.7228 - accuracy: 0.5312 - val_loss: 0.7508 - val_accuracy: 0.4118
# Epoch 3/5
# 1/1 [==============================] - 1s 1s/step - loss: 0.7204 - accuracy: 0.5312 - val_loss: 0.7319 - val_accuracy: 0.4118
# Epoch 4/5
# 1/1 [==============================] - 1s 1s/step - loss: 0.7151 - accuracy: 0.5312 - val_loss: 0.7284 - val_accuracy: 0.4118
# Epoch 5/5
# 1/1 [==============================] - 1s 1s/step - loss: 0.7022 - accuracy: 0.5312 - val_loss: 0.6990 - val_accuracy: 0.5882

# %%
# save the model 
model.save('models/model_{}'.format(label))
# Out:
# WARNING:tensorflow:From /Users/dea/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /Users/dea/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: models/model_education/assets

# %%
# load the model
reconstructed_model = keras.models.load_model('models/model_{}'.format(label))

# %%
preds_df = predict(data_test=dfs_test[label], field=field, max_length=max_length, model=reconstructed_model, tokenizer=tokenizer)

# %%
preds_df.nlargest(30, "pred_1")['title_subtitle'].tolist()
# Out:
# ['We must not let the row over British schools descend into an identity war | Zoe Williams. It’s dispiriting to watch the debate break down into meaningless caricatures, says Guardian columnist Zoe Williams',
#  "England's libraries begin to reopen but grave fears remain over long-term futures. As branches prepare to start restoring services, experts warn a ‘perfect financial storm’ will cause further closures",
#  'Children over 12 should wear face masks to combat Covid, says WHO.  But UK government says masks are not recommended for use by primary or secondary pupils <br>',
#  'Give NHS workers a pay rise as well as a clap | Letters. <strong>Letters: </strong>Readers respond to an article by Ian Macdonald, a psychologist who wrote about the dangers of describing health workers as saints',
#  'Workers’ health and safety must be key | Letters. Employers who fail to prioritise the wellbeing of their staff when they return to work should be held to account',
#  'Donations to be quarantined as UK charity shops plan to reopen. Charities have been badly hit by lockdown, with some reporting millions of pounds a month lost as result of shops being shut',
#  "Arts Council England promises £160m to 'buoy public' during lockdown. Funding announced to protect arts bodies and freelancers as coronavirus hits revenues",
#  'Mental health patients in crisis because of coronavirus cutbacks. Mind survey finds one in four cannot get help as appointments stopped and NHS staff diverted',
#  'Imperial College London warns of cuts in face of coronavirus. Recruitment and capital projects on hold amid plans to furlough staff, says email<br>',
#  'A new website for independent bookshops is just what the industry needs | Simon Jenkins. The high street is clearly facing disaster, but to survive it must make peace with the online world, says Guardian columnist Simon Jenkins',
#  'UK universities issue health warnings over travel to China. Institutions are monitoring staff and students who have recently come from affected areas',
#  'Why is there still no help for so many self-employed people? | Gaby Hinsliff. One in 20 workers has seen their income slump, and had no safety net. Yet the chancellor still isn’t listening, says Guardian columnist Gaby Hinsliff',
#  'Businesses ask for clarity amid confusion over UK lockdown. Many firms unsure whether to stay open, as some employers force staff to keep working',
#  'UK lenders banned from repossessing homes amid coronavirus crisis. Banks and building societies also warned off charging fees for mortgage holidays as customers spend hours trying to contact lenders',
#  "I was so anxious I couldn't sit down': how a high street centre is helping people in crisis. Coronavirus and lockdown have taken a huge toll on people’s mental health. A Stockport drop-in shop is offering vital face-to-face support <br><br>",
#  'Care homes in England say coronavirus death toll has risen to 1,400. Figure far outstrips official total of 217 as testing finally begins for staff and residents<br>',
#  "Restaurants are no longer empty': visitors slowly return to UK's Chinatowns. It has been a bleak few weeks for Chinese business owners amid the coronavirus outbreak but there are signs of a revival",
#  'Which companies are coming through during the coronavirus crisis?.  Some firms have stepped up to support employees, key workers and the NHS – but others have fallen well short ',
#  "Is protective equipment getting to NHS staff on the coronavirus frontline? Here's the truth  | Chris Hopson. Yes, there are shortages but there are huge logistical challenges – and NHS leaders are making massive efforts to fill the gaps, says Chris Hopson of NHS Providers",
#  "New UK teachers' union chief: 'Institutional racism in schools has got to be addressed'. As a black schoolboy in 70s Walsall, Patrick Roach, head of the NASUWT, knew all about racism. Not enough has changed, he says",
#  "The great reopening – how Britain's galleries Covid-proofed themselves. From London to Llandudno to Dundee, museums are back in business. So is it now safe to view art – and how will they cope with the drastic drop in numbers?<br>",
#  "English football's shutdown until April means season may never be completed. Football administrators acknowledge that the current suspension of the season is almost certain to last longer than the initial three weeks",
#  'The Guardian view on the treatment of shielders: first, not last | Editorial. <strong>Editorial: </strong>The handling of those highly vulnerable to coronavirus speaks volumes about attitudes towards chronic illness and disability',
#  'UK bicycle shops and repairers see a surge in business. People are aiming to avoid public transport and stay mobile during the coronavirus outbreak, bike shops report',
#  'I’m an ICU doctor. The NHS isn’t ready for the coronavirus crisis | Tim Cook. As the virus spreads quickly in the UK, hospitals need to step up plans to care for the very sick, recruit more staff and cancel routine surgery, says ICU doctor Tim Cook',
#  'NHS hospitals accused of risking staff lives by forgoing mask fit-tests. Doctors and nurses treating coronavirus patients told to do simple PPE checks themselves<br>',
#  "A devastating loss of funds': UK charities count the cost of Covid. From big appeals to small local organisations, charities face millions less coming in as demand for services rises",
#  'Doctors warn ‘culture of fear’ in NHS could prevent whistleblowing. Royal Free hospital consultant told staff they could be sacked for sharing information with the press or on social media <br>',
#  'Prince William and Kate speak of coronavirus impact on NHS staff. Duke and Duchess of Cambridge say daily stress of helping critically ill patients is not normal<br>',
#  'How a decade of privatisation and cuts exposed England to coronavirus. Government reliance on private contractors follows dramatic changes to local councils and public services']

# %%
preds_df.to_csv("models/preds_{}.csv".format(label))

# %% [markdown]
# ### travel_lockdown

# %%
label = "travel_lockdown"
field = "title_subtitle_bow"
# Split into train and val
data, data_val = train_test_split(dfs_train[label], test_size = 0.2, stratify = dfs_train[label][[label]])
max_length = 100

# %%
model, tokenizer = get_model(max_length = max_length)
history, model = fit_model(model, data, label, field, max_length)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing TFBertModel: ['mlm___cls', 'nsp___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Model: "BERT"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_ids (InputLayer)       [(None, 100)]             0
# _________________________________________________________________
# bert (TFBertMainLayer)       ((None, 100, 768), (None, 109482240
# _________________________________________________________________
# pooled_output (Dropout)      (None, 768)               0
# _________________________________________________________________
# issue (Dense)                (None, 2)                 1538
# =================================================================
# Total params: 109,483,778
# Trainable params: 109,483,778
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# WARNING:tensorflow:Model was constructed with shape (None, 100) for input Tensor("input_ids:0", shape=(None, 100), dtype=int32), but it was called on an input with incompatible shape (None, 73).
# WARNING:tensorflow:Model was constructed with shape (None, 100) for input Tensor("input_ids:0", shape=(None, 100), dtype=int32), but it was called on an input with incompatible shape (None, 73).
# 4/4 [==============================] - ETA: 0s - loss: 0.7227 - accuracy: 0.5216 WARNING:tensorflow:Model was constructed with shape (None, 100) for input Tensor("input_ids:0", shape=(None, 100), dtype=int32), but it was called on an input with incompatible shape (None, 73).
# 4/4 [==============================] - 48s 12s/step - loss: 0.7227 - accuracy: 0.5216 - val_loss: 0.7235 - val_accuracy: 0.4237
# Epoch 2/5
# 4/4 [==============================] - 44s 11s/step - loss: 0.6957 - accuracy: 0.6250 - val_loss: 0.6786 - val_accuracy: 0.7458
# Epoch 3/5
# 4/4 [==============================] - 44s 11s/step - loss: 0.6388 - accuracy: 0.8879 - val_loss: 0.6530 - val_accuracy: 0.7627
# Epoch 4/5
# 4/4 [==============================] - 44s 11s/step - loss: 0.5974 - accuracy: 0.9310 - val_loss: 0.6351 - val_accuracy: 0.7458
# Epoch 5/5
# 4/4 [==============================] - 45s 11s/step - loss: 0.5647 - accuracy: 0.9698 - val_loss: 0.6152 - val_accuracy: 0.8305

# %%
# save the model 
model.save('models/model_{}'.format(label))
# Out:
# WARNING:tensorflow:From /Users/dea/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /Users/dea/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: models/model_travel_lockdown/assets

# %%
# load the model
reconstructed_model = keras.models.load_model('models/model_{}'.format(label))

# %%
preds_df = predict(data_test=dfs_test[label], field=field, max_length=max_length, model=reconstructed_model, tokenizer=tokenizer)

# %%
preds_df.nlargest(30, "pred_1")['title_subtitle'].tolist()
# Out:
# ["Police call for end to 'lockdown-shaming' as a weapon in feuds. Forces receiving thousands of complaints about rule-breaking, fear many are being used to settle scores",
#  'Flexible working will be norm after lockdown, say Barclays and WPP bosses. Crowded office buildings ‘may be a thing of the past’ as staff safety prioritised after Covid-19 crisis',
#  'Chancellor extends UK furlough scheme until end of October. Rishi Sunak says programme will run for further four months as Britain exits lockdown',
#  'Low demand for power causes problems for National Grid. Energy system operator says lower usage during lockdown could put network under stress',
#  'As UK lockdowns ease, fears grow of return to pre-pandemic crime and pollution levels. Carbon emissions, crime and air pollution all fell but are now starting to rebound',
#  'Sales of alcohol, tea and coffee soar in shops since UK lockdown.  Consumers continue to largely eat and drink at home even as Covid-19 lockdown loosens ',
#  "UK police receive 194,000 calls from lockdown 'snitches'. Police chiefs says people finding it harder to observe measures the longer they go on",
#  'Ikea to reopen 19 stores during UK lockdown.  Britain’s biggest furniture chain installs Covid-19 safety measures for 1 June reopening ',
#  'Rishi Sunak preparing to wind down coronavirus furlough scheme from July. UK chancellor set to scale back job retention measure as coronavirus lockdown eases',
#  "Spain's streets turn eerily quiet following coronavirus lockdown. Transformation of usually bustling Madrid and Barcelona spooks the few residents and tourists to venture out",
#  'Coronavirus: Foreign Office finalising plans to evacuate Britons. FCO urgently exploring options for British nationals to leave Hubei province, says No 10',
#  'Record numbers used UK food banks in first month of lockdown.  Charities say government support is failing to protect low-income families',
#  "Lockdown means energy bills will rise. Here's how to keep costs down. There are still many ways to save money though millions of us are mostly stuck indoors",
#  '950,000 apply for universal credit in two weeks of UK lockdown. The government has moved 10,000 staff to process claims and is recruiting more',
#  "Boris Johnson's speech in full: 'first, careful steps' to ease Covid-19 lockdown. Read the full text of the UK prime minister’s address to the nation on Sunday 10 May",
#  "Stephen Timms: 'Universal credit's five-week delay is indefensible'. As work and pensions committee publishes new report, its chair says ‘needlessly punitive’ sanctions must be junked after lockdown ",
#  'Coronavirus: a dozen UK schools send pupils home after Italy trips. Schoolchildren told to self-quarantine for 14 days as precaution',
#  'Donations to be quarantined as UK charity shops plan to reopen. Charities have been badly hit by lockdown, with some reporting millions of pounds a month lost as result of shops being shut',
#  'Labour calls for end to migrant benefit block during lockdown. Shadow immigration minister seeks change to rules that deny access to public funds',
#  "Arts Council England promises £160m to 'buoy public' during lockdown. Funding announced to protect arts bodies and freelancers as coronavirus hits revenues",
#  'Isolating students offered food, toiletries but no financial support by UK universities. UUK produces ‘care checklist’ but critics say it has come too late for many in lockdown',
#  "Vicar's query over lockdown travel fines challenges Hancock.  Health secretary to look at penalties after cleric queries ‘unfairness’ given case of Cummings ",
#  'UK tour for hit show Six and top music acts axed due to local lockdown concerns. Musical producer Kenny Wax says news comes as a disappointment at a time when huge numbers of freelancers are out of work',
#  'Coronavirus: UK universities issue quarantine warning to Chinese students. Students going to China for new year may not be readmitted without quarantine period',
#  'Germany opens some shops as Merkel warns of second wave of coronavirus.  Chancellor cautions against lifting lockdown too quickly saying infections could spike',
#  "Housebuilder Barratt's sales rise on back of stamp duty holiday. UK government’s help-to-buy scheme also helped orders after Covid lockdown ended",
#  'BA, easyJet and Ryanair begin court action over UK quarantine rules. Airlines seeking urgent judicial review of policy that they say could cost thousands of jobs',
#  'Prioritise play when schools reopen, say mental health experts. Letter to UK education secretary warns of impact of coronavirus lockdown on children<br>',
#  'The summer of stress – how to cope with fear and uncertainty in a pandemic. During lockdown, anxiety about our health and the economy was on the rise – and the easing of restrictions has brought new worries. Experts describe how to navigate this period<br>',
#  'Virgin Media to disappear from UK high street. Exclusive: firm’s 53 stores will not reopen after lockdown and staff will be offered other roles']

# %%
preds_df.to_csv("models/preds_{}.csv".format(label))

# %% [markdown]
# ### healthcare

# %%
label = "healthcare"
field = "title_subtitle_bow"
# Split into train and val
data, data_val = train_test_split(dfs_train[label], test_size = 0.2, stratify = dfs_train[label][[label]])
max_length = 100

# %%
model, tokenizer = get_model(max_length = max_length)
history, model = fit_model(model, data, label, field, max_length, epochs = 10)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing TFBertModel: ['nsp___cls', 'mlm___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Model: "BERT"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_ids (InputLayer)       [(None, 100)]             0
# _________________________________________________________________
# bert (TFBertMainLayer)       ((None, 100, 768), (None, 109482240
# _________________________________________________________________
# pooled_output (Dropout)      (None, 768)               0
# _________________________________________________________________
# issue (Dense)                (None, 2)                 1538
# =================================================================
# Total params: 109,483,778
# Trainable params: 109,483,778
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# WARNING:tensorflow:Model was constructed with shape (None, 100) for input Tensor("input_ids:0", shape=(None, 100), dtype=int32), but it was called on an input with incompatible shape (None, 67).
# WARNING:tensorflow:Model was constructed with shape (None, 100) for input Tensor("input_ids:0", shape=(None, 100), dtype=int32), but it was called on an input with incompatible shape (None, 67).
# 2/2 [==============================] - ETA: 0s - loss: 0.7279 - accuracy: 0.4673WARNING:tensorflow:Model was constructed with shape (None, 100) for input Tensor("input_ids:0", shape=(None, 100), dtype=int32), but it was called on an input with incompatible shape (None, 67).
# 2/2 [==============================] - 13s 7s/step - loss: 0.7279 - accuracy: 0.4673 - val_loss: 0.7347 - val_accuracy: 0.4074
# Epoch 2/10
# 2/2 [==============================] - 11s 5s/step - loss: 0.7213 - accuracy: 0.5234 - val_loss: 0.7320 - val_accuracy: 0.4074
# Epoch 3/10
# 2/2 [==============================] - 11s 6s/step - loss: 0.7173 - accuracy: 0.5234 - val_loss: 0.7260 - val_accuracy: 0.4074
# Epoch 4/10
# 2/2 [==============================] - 11s 6s/step - loss: 0.7074 - accuracy: 0.5327 - val_loss: 0.7146 - val_accuracy: 0.4815
# Epoch 5/10
# 2/2 [==============================] - 11s 6s/step - loss: 0.6843 - accuracy: 0.7290 - val_loss: 0.6878 - val_accuracy: 0.7778
# Epoch 6/10
# 2/2 [==============================] - 11s 6s/step - loss: 0.6389 - accuracy: 0.8598 - val_loss: 0.6575 - val_accuracy: 0.7407
# Epoch 7/10
# 2/2 [==============================] - 11s 6s/step - loss: 0.5939 - accuracy: 0.9626 - val_loss: 0.6358 - val_accuracy: 0.8148
# Epoch 8/10
# 2/2 [==============================] - 11s 6s/step - loss: 0.5605 - accuracy: 0.9626 - val_loss: 0.6305 - val_accuracy: 0.7778
# Epoch 9/10
# 2/2 [==============================] - 14s 7s/step - loss: 0.5361 - accuracy: 1.0000 - val_loss: 0.6372 - val_accuracy: 0.7037
# Epoch 10/10
# 2/2 [==============================] - 15s 7s/step - loss: 0.5208 - accuracy: 1.0000 - val_loss: 0.6497 - val_accuracy: 0.6667

# %%
# save the model 
model.save('models/model_{}'.format(label))
# Out:
# WARNING:tensorflow:From /Users/dea/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /Users/dea/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: models/model_healthcare/assets

# %%
# load the model
reconstructed_model = keras.models.load_model('models/model_{}'.format(label))

# %%
preds_df = predict(data_test=dfs_test[label], field=field, max_length=max_length, model=reconstructed_model, tokenizer=tokenizer)

# %%
preds_df.nlargest(30, "pred_1")['title_subtitle'].tolist()
# Out:
# ["NHS groups 'nervous' about lockdown easing without contact tracing. Experts say reliance on human tracking without app could expose England to rise in Covid-19 cases<br>",
#  'Isolation period for those with Covid symptoms may be increased to 10 days. Proposal comes as concern over second wave ‘very high’ in NHS',
#  'Migrant healthcare staff still paying NHS fee despite Johnson U-turn. Many NHS workers charged £400 to use health service after PM said he would axe surcharge',
#  'Emergency law would safeguard jobs of NHS volunteers as virus crisis deepens. Proposals include four-week job guarantee, banning over-70s from big gatherings and stadium closures in battle against Covid-19',
#  'Critical mass of Android users crucial for NHS contact-tracing app. Experts say NHS relying on ‘Android herd immunity’ to overcome Apple-related issues',
#  'NHS coronavirus crisis volunteers frustrated at lack of tasks. Vast majority of 750,000 people who signed up to help are yet to be called into action',
#  'Executive pay capped at private hospitals during NHS takeover. Government limits pay in return for state support as sector struggles for revenue during coronavirus crisis',
#  "England test-and-trace system hit by 'huge' IT problems last month. Exclusive: issues delayed calls to vulnerable coronavirus patients, NHS emails show",
#  'Which companies are coming through during the coronavirus crisis?.  Some firms have stepped up to support employees, key workers and the NHS – but others have fallen well short ',
#  'Birmingham medics investigate high BAME Covid-19 death rate. One Birmingham hospital saw BAME communities make up 64% of coronavirus deaths',
#  'Demand for flu vaccine soars as countries plan for second Covid-19 wave. Manufacturers warn they will struggle to meet demand as governments seek to ease pressure on health services',
#  'Test failures and lack of openness result from pro-private, anti-public ideology | Letters. Letters: <strong>Prof Nick Spence</strong><strong>r</strong> says the private outsourcing of health services is behind the failure of test and trace programmes, while <strong>Dr Ian Davis</strong> says the government should be recruiting staff to test for Covid-19 through the NHS',
#  'Face-mask wearers do not stop washing their hands, study suggests. Scientists say people unlikely to reduce one Covid-19 measure when adopting another',
#  'Research reveals gene role in both dementia and severe Covid-19. Having two copies of e4 variant of ApoE gene linked to double risk of severe Covid-19, study suggests',
#  'BAME groups hit harder by Covid-19 than white people, UK study suggests. Research indicates virus has disproportionate impact on non-white critically ill patients<br>',
#  'Coronavirus has exposed the dangerous failings of NHS marketisation | David McCoy. The coalition government’s 2012 act weakened the healthcare system’s ability to cope with a pandemic, says David McCoy, professor of global public health at Queen Mary University of London',
#  'Scientists ask: could summer heat help beat Covid-19?. Experts are watching carefully to see if this virus will follow the seasonal pattern of flu, but warn that the difference may be minor',
#  'Doubts over take-up of UK government emergency food parcels. Food bank charities also warn vulnerable elderly and those with undiagnosed conditions already going hungry',
#  'We can’t be squeamish about death. We need to confront our worst fears. Patients, their families and their doctors need to be open about the inevitable as the virus sweeps through our population',
#  'Hancock says Covid testing crisis may last weeks as UK hospitals plug gaps. Admission comes as more people with Covid symptoms turn up at A&amp;E and call 111',
#  'Children over 12 should wear face masks to combat Covid, says WHO.  But UK government says masks are not recommended for use by primary or secondary pupils <br>',
#  'Non-woven masks better to stop Covid-19, says Japanese supercomputer. Disposable medical face masks beat those made of cotton or polyester in simulation',
#  "Royal Mail staff 'lack sufficient protection' from coronavirus. Communication Workers Union estimates half of sorting offices have insufficient PPE and sanitiser",
#  "A terrible way to go for £9 an hour': fear at meat plant after three coronavirus deaths. Family of worker at a South Yorkshire food processor with multiple Covid-19 cases and three deaths have criticised treatment of staff",
#  'Britain wins rare praise for leading race to test life-saving Covid drugs. UK’s high infection rate and centralised NHS have enabled Recovery team to help victims across the world',
#  'Are breathing techniques good for your health?. The market is flooded with books and classes claiming ‘breathwork’ can help with mental health, sleep and even Covid-19. But experts are not convinced',
#  'Recovery trial for Covid-19 treatments: what we know so far. The biggest randomised controlled trial of drugs against Covid-19 in the world is already producing results',
#  'Out-of-work households £1,600 worse off during Covid-19 due to austerity. IFS says benefits for families hit by unemployment are worth at least 10% less than in 2011',
#  'Matt Hancock orders urgent review of PHE Covid-19 death figures. Move comes after it emerges statistics may include people who died of other causes',
#  'UK scientists seek  mutant Covid samples from Danish mink farms. Tests will investigate whether virus evades antibodies from recovered patients and those in vaccine trials']

# %%
preds_df.to_csv("models/preds_{}.csv".format(label))

# %% [markdown]
# ### other

# %% [markdown]
# ### politics

# %%
label = "politics"
field = "title_subtitle_bow"
# Split into train and val
data, data_val = train_test_split(dfs_train[label], test_size = 0.2, stratify = dfs_train[label][[label]])
max_length = 100

# %%
model, tokenizer = get_model(max_length = max_length)
history, model = fit_model(model, data, label, field, max_length, epochs = 7)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing TFBertModel: ['mlm___cls', 'nsp___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Model: "BERT"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_ids (InputLayer)       [(None, 100)]             0
# _________________________________________________________________
# bert (TFBertMainLayer)       ((None, 100, 768), (None, 109482240
# _________________________________________________________________
# pooled_output (Dropout)      (None, 768)               0
# _________________________________________________________________
# issue (Dense)                (None, 2)                 1538
# =================================================================
# Total params: 109,483,778
# Trainable params: 109,483,778
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/7
# WARNING:tensorflow:Model was constructed with shape (None, 100) for input Tensor("input_ids:0", shape=(None, 100), dtype=int32), but it was called on an input with incompatible shape (None, 82).
# WARNING:tensorflow:Model was constructed with shape (None, 100) for input Tensor("input_ids:0", shape=(None, 100), dtype=int32), but it was called on an input with incompatible shape (None, 82).
# 3/3 [==============================] - ETA: 0s - loss: 0.7260 - accuracy: 0.5075 WARNING:tensorflow:Model was constructed with shape (None, 100) for input Tensor("input_ids:0", shape=(None, 100), dtype=int32), but it was called on an input with incompatible shape (None, 82).
# 3/3 [==============================] - 36s 12s/step - loss: 0.7260 - accuracy: 0.5075 - val_loss: 0.7319 - val_accuracy: 0.4412
# Epoch 2/7
# 3/3 [==============================] - 27s 9s/step - loss: 0.7200 - accuracy: 0.5149 - val_loss: 0.7183 - val_accuracy: 0.5588
# Epoch 3/7
# 3/3 [==============================] - 27s 9s/step - loss: 0.7174 - accuracy: 0.6045 - val_loss: 0.7254 - val_accuracy: 0.4412
# Epoch 4/7
# 3/3 [==============================] - 35s 12s/step - loss: 0.7134 - accuracy: 0.5149 - val_loss: 0.7050 - val_accuracy: 0.7059
# Epoch 5/7
# 3/3 [==============================] - 39s 13s/step - loss: 0.7007 - accuracy: 0.7687 - val_loss: 0.6935 - val_accuracy: 0.6176
# Epoch 6/7
# 3/3 [==============================] - 37s 12s/step - loss: 0.6716 - accuracy: 0.7836 - val_loss: 0.6385 - val_accuracy: 0.8235
# Epoch 7/7
# 3/3 [==============================] - 59s 20s/step - loss: 0.6251 - accuracy: 0.8507 - val_loss: 0.6493 - val_accuracy: 0.7059

# %%
# save the model 
model.save('models/model_{}'.format(label))
# Out:
# WARNING:tensorflow:From /Users/dea/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /Users/dea/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: models/model_politics/assets

# %%
# load the model
reconstructed_model = keras.models.load_model('models/model_{}'.format(label))

# %%
preds_df = predict(data_test=dfs_test[label], field=field, max_length=max_length, model=reconstructed_model, tokenizer=tokenizer)

# %%
preds_df.nlargest(30, "pred_1")['title_subtitle'].tolist()
# Out:
# ['The Guardian view on Covid and the north-south divide: inequality kills | Editorial. <strong>Editorial: </strong>Boris Johnson won a landslide promising to ‘level up’ the UK. Yet the pandemic threatens to level down the country',
#  'We must not let the government seize back control from doctors | Andrew Lansley. Boris Johnson wants to restructure the NHS. But the lesson of Covid-19 is there is not too little central power, but too much, says former health secretary Andrew Lansley',
#  'Boris Johnson says four nations working on family Christmas plan. Prime minister concedes test-and-trace system ‘hasn’t had as much impact’ as desired',
#  'Bereaved relatives call for immediate inquiry into Covid-19 crisis. Lawyers for 450 people call on Boris Johnson to start public inquiry to help prevent deaths',
#  'As business bigwigs fight to end lockdown, the hero fending them off is … Boris Johnson? | Joel Golby. Tory donors and a few bored people may want the shops to reopen, but let’s not pack away the jigsaws yet, says author Joel Golby',
#  "With Raab at the reins, things are really getting finger-lickin' bad | John Crace. Left in charge of the UK’s front-of-house, the foreign secretary struggled with basic hygiene at the daily press briefing",
#  'Doctors to prescribe bike rides to tackle UK obesity crisis. Boris Johnson to announce new measures to make cycling safer and cheaper to improve health and cut virus risk<br>',
#  "‘After Boris Johnson’s Zoom call, all hell broke loose’: inside the world's favourite video app. Ten years ago, Silicon Valley had written off Zoom. Now it’s used by everyone from princes to piano teachers",
#  "If we follow Boris Johnson's advice, coronavirus will spread | David Hunter. A large-scale return to work without the ability to test, trace and isolate risks creating super-spreader events, says epidemiology professor David Hunter",
#  "Boris Johnson's education catch-up plans do not reflect reality. Experts fear it will be impossible to deliver on tutoring pledge for a million children by September",
#  "In 12 weeks we can turn the tide': now we can ask – was Boris Johnson right?. Coronavirus deaths and infections are dropping, but experts fear lockdown is being eased too soon",
#  'Boris Johnson promises ‘maximum caution’ in easing Covid-19 restrictions.  Downing Street pours cold water on reports lockdown could be lifted from Monday ',
#  "Keir Starmer accuses PM of placing parents in 'impossible position'. Labour leader condemned Boris Johnson’s call for employees to return to work without efficient childcare support",
#  'Matt Hancock sets target of 100,000 coronavirus tests a day. Health secretary ‘determined’ to reach six-figure goal for England by end of April',
#  'Boris Johnson to warn UK: tougher lockdown may be necessary. Outbreak will get worse before it gets better, PM tells nation as death toll hits 1,000',
#  'Boris Johnson urged to set out recovery plan for schools in England. Ministers warned country may face ‘educational poverty’ if no strategy in place for September',
#  'Former chancellor Alistair Darling calls for emergency VAT cut. Move to stimulate spending as part of Covid-19 recovery plan makes sense, says politician',
#  'Johnson promises plan next week for return to schools and work. PM says UK is past peak of coronavirus and vows to produce road map for economy',
#  'Science and politics: a complicated formula | Letters. Letters: <strong>Prof Ravi Mahajan</strong> and <strong>Alan Walker</strong> respond to Richard Horton’s article in which he questions how scientists can stand by this government. Plus <strong>Philip Barber </strong>wonders why we are being led by science, while simultaneously disregarding it',
#  'Bleak day for UK as Centrica, Johnson Matthey and Heathrow announce big job losses. British Gas to slash 5,000 jobs, Johnson Matthey, 2,500, as Heathrow Airport launches redundancy programme',
#  'PM tells Britons to avoid non-essential travel and contact. Boris Johnson announces series of new measures including 14-day isolation for households with symptoms',
#  'The Guardian view on the UK’s testing failure: much to learn from Germany | Editorial. <strong>Editorial:</strong> Matt Hancock says our European rival did better because of its industrial strengths. But it also benefited from its political ones',
#  'Black Lives Matter protests risk spreading Covid-19, says Hancock. Health secretary denies UK is racist, and repeats calls to keep to distancing rules at rallies',
#  'To get people to use face masks, we need solidarity, not shaming | Frances Ryan. To tackle coronavirus in England, Boris Johnson should commit to teaching not just the science but the ethics behind the rules, says Guardian columnist Frances Ryan',
#  'Matt Hancock: England in good position to avoid major Covid resurgence. Health secretary hails weekly mass testing programme but admits he is ‘very worried’ about surge in cases',
#  "Covid can change UK like 'new Jerusalem' of 1940s, Johnson claims. Prime minister tells virtual Tory conference that country must not return to status quo",
#  "Germany's Covid-19 expert: 'For many, I'm the evil guy crippling the economy'. Germany’s leading coronavirus expert Christian Drosten on Merkel’s leadership, the UK response and the ‘prevention paradox’Coronavirus – latest updatesSee all our coronavirus coverage",
#  'Coronavirus: Boris Johnson to hold Cobra meeting as UK death toll hits three. Prime minister to consider bringing in tougher measures to delay spread of outbreak',
#  'Matt Hancock says he backs any police action against Neil Ferguson. Met says scientist will face no further action after UK health secretary says lockdown breach leaves him speechless',
#  'Typhoid Dido proves fluent in management bollocks and contradiction | John Crace. Harding has the appearance of someone prepared to put the hours in, even if they aren’t put to much obvious use']

# %%
preds_df.to_csv("models/preds_{}.csv".format(label))

# %% [markdown]
# ### environment

# %%
label = "environment"
field = "title_subtitle_bow"
# Split into train and val
data, data_val = train_test_split(dfs_train[label], test_size = 0.2, stratify = dfs_train[label][[label]])
max_length = 100

# %%
model, tokenizer = get_model(max_length = max_length)
history, model = fit_model(model, data, label, field, max_length, epochs = 7)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing TFBertModel: ['mlm___cls', 'nsp___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Model: "BERT"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_ids (InputLayer)       [(None, 100)]             0
# _________________________________________________________________
# bert (TFBertMainLayer)       ((None, 100, 768), (None, 109482240
# _________________________________________________________________
# pooled_output (Dropout)      (None, 768)               0
# _________________________________________________________________
# issue (Dense)                (None, 2)                 1538
# =================================================================
# Total params: 109,483,778
# Trainable params: 109,483,778
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/7
# WARNING:tensorflow:Model was constructed with shape (None, 100) for input Tensor("input_ids:0", shape=(None, 100), dtype=int32), but it was called on an input with incompatible shape (None, 85).
# WARNING:tensorflow:Model was constructed with shape (None, 100) for input Tensor("input_ids:0", shape=(None, 100), dtype=int32), but it was called on an input with incompatible shape (None, 85).
# 1/1 [==============================] - ETA: 0s - loss: 0.7243 - accuracy: 0.4615WARNING:tensorflow:Model was constructed with shape (None, 100) for input Tensor("input_ids:0", shape=(None, 100), dtype=int32), but it was called on an input with incompatible shape (None, 85).
# 1/1 [==============================] - 3s 3s/step - loss: 0.7243 - accuracy: 0.4615 - val_loss: 0.7153 - val_accuracy: 0.5714
# Epoch 2/7
# 1/1 [==============================] - 1s 635ms/step - loss: 0.7214 - accuracy: 0.5000 - val_loss: 0.7211 - val_accuracy: 0.5714
# Epoch 3/7
# 1/1 [==============================] - 1s 644ms/step - loss: 0.7095 - accuracy: 0.8846 - val_loss: 0.7099 - val_accuracy: 0.7143
# Epoch 4/7
# 1/1 [==============================] - 1s 633ms/step - loss: 0.7031 - accuracy: 0.6538 - val_loss: 0.7106 - val_accuracy: 0.8571
# Epoch 5/7
# 1/1 [==============================] - 1s 642ms/step - loss: 0.6816 - accuracy: 0.9615 - val_loss: 0.7131 - val_accuracy: 0.5714
# Epoch 6/7
# 1/1 [==============================] - 1s 708ms/step - loss: 0.6582 - accuracy: 1.0000 - val_loss: 0.7198 - val_accuracy: 0.4286
# Epoch 7/7
# 1/1 [==============================] - 1s 727ms/step - loss: 0.6380 - accuracy: 1.0000 - val_loss: 0.6835 - val_accuracy: 0.8571

# %%
# save the model 
model.save('models/model_{}'.format(label))
# Out:
# WARNING:tensorflow:From /Users/dea/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /Users/dea/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: models/model_environment/assets

# %%
# load the model
reconstructed_model = keras.models.load_model('models/model_{}'.format(label))

# %%
preds_df = predict(data_test=dfs_test[label], field=field, max_length=max_length, model=reconstructed_model, tokenizer=tokenizer)

# %%
preds_df.nlargest(30, "pred_1")['title_subtitle'].tolist()
# Out:
# ['The coronavirus has exposed the imbalances in modern Britain. A bigger, smarter state is now needed, with devolved decisions, a greener economy and a stronger safety net',
#  "In 12 weeks we can turn the tide': now we can ask – was Boris Johnson right?. Coronavirus deaths and infections are dropping, but experts fear lockdown is being eased too soon",
#  "The perfect time to start': how book clubs are enduring and flourishing during Covid-19. As the world goes into lockdown, more reading groups are moving on to Zoom, Twitter and Instagram to bring readers together",
#  'What will coronavirus mean for the British economy?.  As the UK faces what may be its worst ever recession, we begin a monthly series exploring the financial shock to business and living standards',
#  'Our blueprint for a post-coronavirus future | Letters. As we recover from the pandemic, here’s how we must create a more caring and united society',
#  'Coronavirus: looking for good news – Run for Heroes and an opera-singing doctor.  Running fundraiser for NHS and frontline workers raises over £1m and the BBC announces a star-studded Big Night In ',
#  'After-work drinks by video: how to survive 100 days of solitude. Fortitude, imagination and humour shine through as readers tell us about their self-isolation<br>',
#  'Shielding in the UK: how are you feeling about the winter months?. We would like to hear from those who are high risk on their thoughts on the coronavirus pandemic and the next few months<br>',
#  'Socially distanced outdoor music venue to open in Newcastle in August. Arena at Newcastle Racecourse will feature individual viewing platforms spaced two metres apart',
#  '‘I feel like a 1950s housewife’: how lockdown has exposed the gender divide. It’s still expected that women will make their jobs fit around childcare and home schooling, while a man’s job comes first',
#  'Coronavirus: 21 March at a glance. A summary of today’s biggest developments in the global coronavirus outbreak',
#  "The extreme loneliness of lockdown: 'Even though my partner is here, I’m struggling to cope'. After weeks of isolation, many people are falling prey to loneliness. Guardian readers and experts offer their experience and advice on how to get through this distressing, dislocating time",
#  "Isolation and contemplation: Nadav Kander's visual response to coronavirus. In the first part of our series commissioned in conjunction with the Prix Pictet, a global award in photography and sustainability, photographers who have won or been shortlisted for the award over the last decade have been asked to make a personal response to the Covid-19 crisis. Here <strong>Nadav Kander</strong> speaks about his submission Solitude - Quietude – Contemplation",
#  'Global leaders send messages of support to Boris Johnson. Best wishes flood in from across the world for the UK prime minister and his family',
#  'Coronavirus 3 May: at a glance. A summary of the biggest developments in the global coronavirus outbreak',
#  'Britain should be taking coronavirus more seriously | Letters. <strong>Letters:</strong> Readers respond to the latest developments in the spread of Covid-19',
#  "Easter is a time to connect. So even in isolation, let's cherish the ties that bind. During the lockdown, we’ve discovered that what truly matters is empathy and kindness and collaboration",
#  "The great reopening – how Britain's galleries Covid-proofed themselves. From London to Llandudno to Dundee, museums are back in business. So is it now safe to view art – and how will they cope with the drastic drop in numbers?<br>",
#  "Of course I am worried': Chinese visitors to UK torn over coronavirus. Tourists say they are trying to enjoy their trip but fear for those at home",
#  'How to break the lockdown – inside the 24 April Guardian Weekly. Our latest coronavirus special edition looks at how different countries are taking different routes to normality. ',
#  'The summer of stress – how to cope with fear and uncertainty in a pandemic. During lockdown, anxiety about our health and the economy was on the rise – and the easing of restrictions has brought new worries. Experts describe how to navigate this period<br>',
#  'The sudden fight for the supreme court: inside the 25 September Guardian Weekly. This week we look about the already bitter fight to replace Ruth Bader Ginsburg on the US supreme court. Plus, lessons from around the world for the countries hitting a new Covid-19 wave. ',
#  'Coronavirus: is this the start of a second wave and is the UK prepared?. Cases of Covid-19 are rising here and across Europe as UK universities plan to reopen. What is the outlook for autumn?',
#  'What does WhatsApp mean for democracy? Inside 10 July Guardian Weekly. This week, we look at how the messaging service has changed the way we communicate. Plus, stories from Hong Kong and the coronavirus disaster in the US and Latin America. ',
#  'Closed borders and ‘black weddings’: what the 1918 flu teaches us about coronavirus. The influenza of 1918 killed up to 100 million people. What lessons does it offer for our current health crisis?',
#  'Bolton residents: have you been able to get tested for coronavirus?. We would like to hear from people in the northern town about their testing experiences and the issues they have encountered ',
#  'Visitors return to Spain as coronavirus state of emergency ends. The Spanish government has launched a publicity campaign to boost crucial tourism industry',
#  'Mortgage holidays: a break is tempting, but it will cost you. About 2m Britons have paused payments in the coronavirus crisis. Readers share their concerns',
#  "My company has gone fully remote and I'm despairing': who wins in the new world of working from home?. As we move away from the traditional 9 to 5, the boundaries between office and home are increasingly blurred. Meet the bosses trying to get it right",
#  'Johnson shows again he can get away with stuff other PMs couldn’t. For a leader to holiday while floods hit the country isn’t normal, but ours believes in his own exceptionalism']

# %%
preds_df.to_csv("models/preds_{}.csv".format(label))

# %% [markdown]
# ### social_issues

# %%
label = "social_issues"
field = "title_subtitle_bow"
# Split into train and val
data, data_val = train_test_split(dfs_train[label], test_size = 0.2, stratify = dfs_train[label][[label]])
max_length = 100

# %%
model, tokenizer = get_model(max_length = max_length)
history, model = fit_model(model, data, label, field, max_length, epochs = 7)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing TFBertModel: ['mlm___cls', 'nsp___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Model: "BERT"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_ids (InputLayer)       [(None, 100)]             0
# _________________________________________________________________
# bert (TFBertMainLayer)       ((None, 100, 768), (None, 109482240
# _________________________________________________________________
# pooled_output (Dropout)      (None, 768)               0
# _________________________________________________________________
# issue (Dense)                (None, 2)                 1538
# =================================================================
# Total params: 109,483,778
# Trainable params: 109,483,778
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/7
# WARNING:tensorflow:Model was constructed with shape (None, 100) for input Tensor("input_ids:0", shape=(None, 100), dtype=int32), but it was called on an input with incompatible shape (None, 67).
# WARNING:tensorflow:Model was constructed with shape (None, 100) for input Tensor("input_ids:0", shape=(None, 100), dtype=int32), but it was called on an input with incompatible shape (None, 67).
# 4/4 [==============================] - ETA: 0s - loss: 0.7241 - accuracy: 0.4974 WARNING:tensorflow:Model was constructed with shape (None, 100) for input Tensor("input_ids:0", shape=(None, 100), dtype=int32), but it was called on an input with incompatible shape (None, 67).
# 4/4 [==============================] - 40s 10s/step - loss: 0.7241 - accuracy: 0.4974 - val_loss: 0.7194 - val_accuracy: 0.5102
# Epoch 2/7
# 4/4 [==============================] - 35s 9s/step - loss: 0.7174 - accuracy: 0.5231 - val_loss: 0.7195 - val_accuracy: 0.4694
# Epoch 3/7
# 4/4 [==============================] - 35s 9s/step - loss: 0.7079 - accuracy: 0.5179 - val_loss: 0.7028 - val_accuracy: 0.6327
# Epoch 4/7
# 4/4 [==============================] - 35s 9s/step - loss: 0.6921 - accuracy: 0.7436 - val_loss: 0.6821 - val_accuracy: 0.7347
# Epoch 5/7
# 4/4 [==============================] - 35s 9s/step - loss: 0.6605 - accuracy: 0.7846 - val_loss: 0.6475 - val_accuracy: 0.7551
# Epoch 6/7
# 4/4 [==============================] - 37s 9s/step - loss: 0.6117 - accuracy: 0.8667 - val_loss: 0.6408 - val_accuracy: 0.7347
# Epoch 7/7
# 4/4 [==============================] - 39s 10s/step - loss: 0.5750 - accuracy: 0.9077 - val_loss: 0.6606 - val_accuracy: 0.6939

# %%
# save the model 
model.save('models/model_{}'.format(label))
# Out:
# WARNING:tensorflow:From /Users/dea/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /Users/dea/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: models/model_social_issues/assets

# %%
# load the model
reconstructed_model = keras.models.load_model('models/model_{}'.format(label))

# %%
preds_df = predict(data_test=dfs_test[label], field=field, max_length=max_length, model=reconstructed_model, tokenizer=tokenizer)

# %%
preds_df.nlargest(30, "pred_1")['title_subtitle'].tolist()
# Out:
# ['It is time we made masks compulsory | Letters. <strong>Letters: </strong>Countries where face mask use is widespread have seen fewer Covid-19 deaths, writes <strong>Prof David Smith</strong>, while <strong>Philip Rundall</strong> thinks shops should do more to encourage customers to wear them',
#  'Care home crisis is the result of years of neglect | Letters. Letters: <strong>Bill Shaw</strong> says the Thatcher government systematically dismantled social care provision, while <strong>Les Bright </strong>highlights what went wrong with private services. Plus letters from <strong>Tom Wilson</strong> and <strong>J</strong><strong>anet Broadmore</strong>',
#  'Universities have let their students down | Letters. <strong>Letters: </strong>Current difficulties were predictable and avoidable, writes <strong>one academic</strong>, while <strong>Maria Gajewska </strong>wonders when a fee refund might be due. Meanwhile, <strong>William Proctor </strong>believes it is the government, not institutions, that bears responsibility for the crisis ',
#  'Why few Britons pick fruit on our farm | Letter. <strong>Letters: </strong>For distancing reasons we are minimising the number of people on the campsite so only have room for those who have worked for us before, but we are keen to recruit local people and have been in touch with many, writes <strong>Andrew Chesson</strong>',
#  'No room for complacency over Covid death toll | Letters. Letters:<strong> </strong><strong>Prof Steve Tombs </strong>on how changing the criteria for recording deaths has skewed the data, and <strong>Richard Post </strong>on the trouble with tracking deaths against cases ',
#  'In lockdown, parents are mastering the art of the meme. What could go wrong? | Eleanor Margolis. Who thought the family WhatsApp group would alleviate our existential dread? We’re in strange times, says Eleanor Margolis ',
#  'Myths and realities of public sector pay hikes. <strong>Letters: </strong><strong>George Binette </strong>says less than a quarter of workers will benefit, while<strong> </strong><strong>Vic Rayner </strong>decries the fact that care home staff have been forgotten and <strong>Angela Pickering</strong> believes the headlines are just government spin. Plus <strong>Marc Boix Codony</strong>, a consultant neurologist, is clear where the money should go – and it’s not to him',
#  'Reopening schools is a dangerous move | Letters. <strong>Letters: </strong>Teacher <strong>Sarah Humpleby </strong>says it is her social responsibility not to participate in this madness, <strong>Jenny Owen </strong>is concerned about the lack of protective equipment for teaching staff, while <strong>Stan </strong><strong>Labovitch </strong>wonders if PPE will be on the curriculum',
#  "Covid has hit England's older people hardest. This time, we need better care | Dorothy Byrne. Older patients too often receive a raw deal from the health service. The second wave is a chance to put that right, says Dorothy Byrne, editor-at-large at Channel 4",
#  'Covid-19 reveals the alarming truth that many children can’t wash their hands at school | Laura McInerney. A survey found that 37% of teachers said they did not have hot water and soap available for pupils',
#  'Can I go clubbing? Yes –\xa0in New Zealand! Your guide to easing and the arts. Are seatless, stroll-through shows the future of theatre? Can one-way dancing save nightclubs? Could budding indie bands storm Wembley stadium? Scientists imagine the arts after Covid-19',
#  "Why you shouldn't fall for the panic about Britain's public debt | Daniela Gabor. The right wants to spread alarm about government borrowing, but it’s a sound, affordable response to the pandemic, says the academic Daniela Gabor",
#  'We need to protect all frontline workers. <strong>Letters: </strong>A mental health support worker on looking after patients without proper PPE and two parents concerned for their social worker and care worker children. Plus <strong>Will Gelson </strong>asks us to remember all healthcare professionals putting their lives at risk',
#  'How coronavirus is spurring the cause of a united Ireland | Una Mullally. A pandemic that knows no borders has arrived at the same time as political support for unity is growing, says the Irish Times columnist Una Mullally',
#  'Winning by a nose: the dogs being trained to detect signs of Covid-19. In the battle against the virus, we have an unlikely ally. Already used to detect drugs and weapons, dogs are now being trained to sniff out when humans have the virus. Tim Lewis meets the trainers and their hounds',
#  "The Guardian view on Johnson's Covid-19 plan: doubt, deny and dismiss | Editorial. <strong>Editorial:</strong> Rather than admit responsibility for being behind the curve, ministers instead seek to delegitimise the media for asking questions about why Britain failed",
#  "Johnson has failed on social care. That's why he is dodging a coronavirus inquiry | Polly Toynbee. This is a very dangerous area for the government – and not just because of the obvious blunders of the pandemic, says Guardian columnist Polly Toynbee",
#  '‘We’ve learned how we need to act’: Spain braces for second wave of Covid. An increase in infections, particularly among younger age groups, is causing a spike centred on the area around Madrid',
#  "It all crumbled': pop stars on mental health in the age of Covid. Figures show number of adults with depression in UK has doubled with young people hit most<br>",
#  'The Guardian view on the Covid-19 strategy: insuring against a killer. <strong>Editorial:</strong> A virus that could almost double the number of deaths a year in the UK was left to spread untracked and could have overwhelmed the NHS. That can’t be allowed to happen again',
#  'Out with pub bores, back in with the experts | Stewart Lee. Boffins are suddenly in fashion again ... ‘waving their statistics and strategies like prayer flags. Help us, experts! We are sorry!!’',
#  "Eat out to help out': a forlorn dream for those struggling to feed a family. The government is spending about £500m to pay people to go to restaurants, while families in poverty get next to nothing ",
#  "We found the first cat in the UK with Covid-19 - but there's no need to panic | Willie Weir. The feline had caught coronavirus from its owners, but our research shows it’s a rare occurrence, says Willie Weir,<strong> </strong>professor of veterinary infectious disease",
#  'Politics are a matter of life and death. No wonder more Scots want to leave the UK | Adam Ramsay. Coronavirus has revealed a hard truth about devolution: the Scottish government has some flexibility, but on the UK’s terms, says openDemocracy co-editor Adam Ramsay',
#  "The UK's private debt crisis will make this recession so much worse | Christine Berry. People and businesses were already over-indebted before the pandemic. The government’s schemes have made things worse, says the writer and researcher Christine Berry",
#  'Why is there still no help for so many self-employed people? | Gaby Hinsliff. One in 20 workers has seen their income slump, and had no safety net. Yet the chancellor still isn’t listening, says Guardian columnist Gaby Hinsliff',
#  'The Rules of Contagion by Adam Kucharski review – outbreaks of all kinds. Modellers have a saying: “If you’ve seen one pandemic, you’ve seen … one pandemic.” But patterns can be established to do with how things spread ',
#  'To get people to use face masks, we need solidarity, not shaming | Frances Ryan. To tackle coronavirus in England, Boris Johnson should commit to teaching not just the science but the ethics behind the rules, says Guardian columnist Frances Ryan',
#  "This crisis calls for massive government intervention: here's how to do it | Emmanuel Saez and Gabriel Zucman. The state should step in as payer of last resort for businesses facing shutdown as coronavirus hits them hard, say economics professors Emmanuel Saez and Gabriel Zucman",
#  'As business bigwigs fight to end lockdown, the hero fending them off is … Boris Johnson? | Joel Golby. Tory donors and a few bored people may want the shops to reopen, but let’s not pack away the jigsaws yet, says author Joel Golby']

# world/2020/apr/22/eu-turns-up-pressure-on-matt-...        yes   NaN      NaN
# business/2020/jun/14/incoherent-government-make...        NaN   NaN      yes
# business/2020/apr/02/sainsburys-revives-bicycle...        NaN   NaN      NaN
# politics/2020/jul/17/boris-johnson-coronavirus-...        NaN   yes      NaN
# world/2020/may/31/how-a-decade-of-privatisation...        NaN   NaN      yes
# business/2020/oct/31/chocolate-sales-soar-uk-sh...        NaN   yes      NaN
# business/2020/sep/23/uk-supermarkets-urge-shopp...        NaN   NaN      NaN
# business/2020/apr/03/coronavirus-sainsburys-to-...        NaN   yes      NaN
# business/2020/apr/29/jd-wetherspoon-plans-to-re...        NaN   NaN      NaN
#
#                                                    environment social_issues
# id
# environment/2020/apr/17/coronavirus-profiteers-...         yes           NaN
# technology/2020/mar/13/covid-19-could-cause-per...         NaN           yes
# money/2020/may/31/will-investing-in-our-newfoun...         NaN           NaN
# environment/2020/mar/18/billion-dollar-wildlife...         NaN           NaN
# global-development/2020/mar/25/africa-leads-cal...         NaN           NaN
# business/2020/aug/24/mike-ashleys-frasers-group...         NaN           NaN
# business/2020/jun/10/goldman-sachs-closes-marcu...         NaN           NaN
# environment/2020/mar/24/covid-19-economic-rescu...         yes           NaN
# money/2020/nov/07/uk--stamp-duty-holiday-deadli...         NaN           NaN
# business/2020/nov/05/future-market-for-covid-va...         NaN           NaN
# politics/2020/jun/29/absolutely-fanciful-boris-...         NaN           NaN
# business/2020/jun/09/hoseasons-cottages-com-ref...         NaN           NaN
# business/nils-pratley-on-finance/2020/mar/12/tr...         NaN           NaN
# money/2020/mar/13/uk-travel-insurers-stopping-p...         NaN           NaN
# society/2020/sep/24/pharmacies-in-england-pause...         NaN           NaN
# uk-news/2020/oct/17/greater-manchester-lockdown...         NaN           NaN
# world/2020/may/05/eurostar-backtracks-over-coro...         NaN           NaN
# business/2020/jun/01/shopper-numbers-surge-36-a...         NaN           NaN
# business/2020/mar/30/hammerson-shop-rent-taking...         NaN           NaN
# business/2020/apr/29/flexible-working-will-be-n...         NaN           yes
# commentisfree/2020/mar/17/governments-crisis-co...         NaN           NaN
# world/2020/apr/22/eu-turns-up-pressure-on-matt-...         NaN           NaN
# business/2020/jun/14/incoherent-government-make...         NaN           NaN
# business/2020/apr/02/sainsburys-revives-bicycle...         NaN           NaN
# politics/2020/jul/17/boris-johnson-coronavirus-...         NaN           NaN
# world/2020/may/31/how-a-decade-of-privatisation...         NaN           yes
# business/2020/oct/31/chocolate-sales-soar-uk-sh...         NaN           NaN
# business/2020/sep/23/uk-supermarkets-urge-shopp...         NaN           NaN
# business/2020/apr/03/coronavirus-sainsburys-to-...         NaN           NaN
# business/2020/apr/29/jd-wetherspoon-plans-to-re...         NaN           NaN

# %%
preds_education = pd.read_csv("./models/preds_education.csv", index_col=0)
# not good

# %%
preds_education.nlargest(30, "pred_1")
# Out:
#                                                       pred_0    pred_1  \
# id
# commentisfree/2020/may/19/british-schools-ident...  0.351586  0.648414
# books/2020/jul/03/uk-libraries-reopen-grave-fea...  0.353205  0.646795
# uk-news/2020/feb/28/johnson-shows-get-away-with...        NaN   NaN      yes
#
#                                                     environment social_issues
# id
# business/2020/may/03/the-coronavirus-has-expose...          NaN           yes
# world/2020/jun/11/in-12-weeks-we-can-turn-the-t...          NaN           NaN
# books/2020/mar/26/the-perfect-time-to-start-how...          NaN           NaN
# world/2020/apr/24/what-will-coronavirus-mean-fo...          NaN           NaN
# commentisfree/2020/may/24/letters-our-blueprint...          NaN           yes
# news/2020/apr/13/coronavirus-looking-for-good-n...          NaN           NaN
# world/2020/mar/20/after-work-drinks-by-video-ho...          NaN           NaN
# world/2020/sep/28/shielding-in-the-uk-how-are-y...          NaN           yes
# music/2020/jul/03/socially-distanced-outdoor-mu...          NaN           NaN
# world/2020/may/03/i-feel-like-a-1950s-housewife...          NaN           yes
# world/2020/mar/21/coronavirus-21-march-at-a-gla...          NaN           NaN
# society/2020/apr/28/the-extreme-loneliness-of-l...          NaN           yes
# world/2020/jun/05/isolation-and-contemplation-n...          NaN           NaN
# politics/2020/apr/06/global-leaders-send-messag...          NaN           NaN
# world/2020/may/03/coronavirus-latest-at-a-glanc...          NaN           NaN
# world/2020/feb/25/britain-should-be-taking-coro...          NaN           NaN
# commentisfree/2020/apr/12/easter-is-a-time-to-c...          NaN           NaN
# artanddesign/2020/jul/08/great-reopening-britai...          NaN           NaN
# world/2020/feb/01/of-course-i-am-worried-chines...          NaN           NaN
# news/2020/apr/22/how-to-break-the-lockdown-insi...          NaN           NaN
# lifeandstyle/2020/jul/12/the-summer-of-stress-h...          NaN           NaN
# news/2020/sep/23/the-sudden-fight-for-the-supre...          NaN           NaN
# world/2020/sep/13/is-this-the-start-of-a-second...          NaN           NaN
# news/2020/jul/08/what-does-whatsapp-mean-for-de...          NaN           yes
# world/2020/mar/11/closed-borders-and-black-wedd...          NaN           NaN
# world/2020/sep/16/bolton-residents-have-you-bee...          NaN           NaN
# world/2020/jun/21/visitors-return-to-spain-as-c...          NaN           NaN
# money/2020/may/09/mortgage-holidays-cost-paymen...          NaN           NaN
# business/2020/sep/12/my-company-has-gone-fully-...          NaN           yes
# uk-news/2020/feb/28/johnson-shows-get-away-with...          NaN           NaN

# %%
preds_healthcare = pd.read_csv("./models/preds_healthcare.csv", index_col=0)
# so-so; re-examine

# %%
preds_healthcare[preds_healthcare['pred_1']>0.5]['title_subtitle'].tolist()
# Out:
# ['Pupils begin studying at home – a challenge for them, parents and teachers. Schools provide online classes, but some pupils struggle to stay motivated after exams were cancelled',
#  'No 10 tells holidaymakers to claim universal credit for Covid-19 quarantine. Unions urge government to ensure statutory sick pay for those forced to self-isolate after travelling in Spain',
#  'Face-mask wearers do not stop washing their hands, study suggests. Scientists say people unlikely to reduce one Covid-19 measure when adopting another',
#  'Hancock says Covid testing crisis may last weeks as UK hospitals plug gaps. Admission comes as more people with Covid symptoms turn up at A&amp;E and call 111',
#  'Three more Midlands meat factory workers test positive for coronavirus. Health officials in England and Wales monitoring new cases linked to food processing plants ',
#  'Yasmin Qureshi MP in hospital with pneumonia after positive Covid test. Bolton MP and shadow international development minister being treated after condition worsens',
#  "A terrible way to go for £9 an hour': fear at meat plant after three coronavirus deaths. Family of worker at a South Yorkshire food processor with multiple Covid-19 cases and three deaths have criticised treatment of staff",
#  'Which companies are coming through during the coronavirus crisis?.  Some firms have stepped up to support employees, key workers and the NHS – but others have fallen well short ',
#  'UK coronavirus border controls more effective if done earlier, MPs told. Health experts also challenge government’s assessment of impact of imported cases',
#  'Woman, 90, to climb Highland mountain on her stairs to help NHS. Margaret Payne from Scotland is latest nonagenarian to raise money for coronavirus crisis',
#  'Children over 12 should wear face masks to combat Covid, says WHO.  But UK government says masks are not recommended for use by primary or secondary pupils <br>',
#  'British American Tobacco working on plant-based coronavirus vaccine.  Cigarette maker says tobacco plants offer potential for faster and safer drug development ',
#  'Doubts over take-up of UK government emergency food parcels. Food bank charities also warn vulnerable elderly and those with undiagnosed conditions already going hungry',
#  "Ending Covid-19 via herd immunity is 'a dangerous fallacy'. Prominent scientists sign open letter saying strategy is ‘unsupported by evidence’ ",
#  'Ministers and north of England leaders clash over further Covid restrictions. Decision expected on whether to extend tier 3 rules to Greater Manchester and Lancashire',
#  'Nobel laureates call on UK to back infecting volunteers with Covid for vaccine trials. Exclusive: scientists say such tests are ethical and could shorten pandemic',
#  'UK charities face soaring demand for grief counselling due to Covid-19. Bereaved families say they have been abandoned by the government',
#  'Low demand for power causes problems for National Grid. Energy system operator says lower usage during lockdown could put network under stress',
#  'Coronavirus UK: BAME women suffer harder financial hit. Study also shows that psychological consequences are worse than for white women ',
#  "NHS groups 'nervous' about lockdown easing without contact tracing. Experts say reliance on human tracking without app could expose England to rise in Covid-19 cases<br>",
#  'Fears of virus risk to grandparents offering emergency childcare. School closures could force parents to call on older relatives for help – perhaps exposing them to infection',
#  'Emergency law would safeguard jobs of NHS volunteers as virus crisis deepens. Proposals include four-week job guarantee, banning over-70s from big gatherings and stadium closures in battle against Covid-19',
#  'Britain wins rare praise for leading race to test life-saving Covid drugs. UK’s high infection rate and centralised NHS have enabled Recovery team to help victims across the world',
#  'UK care home bosses call for help from medics as death toll grows. Five of the largest care home providers have now recorded a total of at least 1,052 deaths',
#  "MPs expected to approve plans for 'virtual parliament'. Proposal would allow 120 MPs to take part using Zoom app while another 50 sit in chamber",
#  'Three mobile cuts off customers stranded abroad due to Covid crisis. Mobile provider cuts off customers stranded abroad due to Covid crisis',
#  "England test-and-trace system hit by 'huge' IT problems last month. Exclusive: issues delayed calls to vulnerable coronavirus patients, NHS emails show",
#  'Recovery trial for Covid-19 treatments: what we know so far. The biggest randomised controlled trial of drugs against Covid-19 in the world is already producing results',
#  'Critical mass of Android users crucial for NHS contact-tracing app. Experts say NHS relying on ‘Android herd immunity’ to overcome Apple-related issues',
#  'BAME groups hit harder by Covid-19 than white people, UK study suggests. Research indicates virus has disproportionate impact on non-white critically ill patients<br>',
#  'Matt Hancock orders urgent review of PHE Covid-19 death figures. Move comes after it emerges statistics may include people who died of other causes',
#  'Essex GP, 78, among latest NHS workers to die from coronavirus. Kamlesh Kumar Masson described as ‘honest, kind and generous man’<br>',
#  'UK scientists seek  mutant Covid samples from Danish mink farms. Tests will investigate whether virus evades antibodies from recovered patients and those in vaccine trials',
#  '‘We’ve learned how we need to act’: Spain braces for second wave of Covid. An increase in infections, particularly among younger age groups, is causing a spike centred on the area around Madrid',
#  'Fears that cancelling exams will hit BAME and poor pupils worst.  Experts saying basing results on predicted grades will disadvantage some students ',
#  "UK 'must spend extra £22bn' to help workers facing layoffs, urges thinktank. Resolution Foundation proposes new subsidy modelled on maternity pay with warning 1m staff at risk of redundancy",
#  'Research reveals gene role in both dementia and severe Covid-19. Having two copies of e4 variant of ApoE gene linked to double risk of severe Covid-19, study suggests',
#  "At 75, I've volunteered for a Covid vaccine trial. It could set people free. Some of my friends think I’m mad but we need to know people my age can go out safely again",
#  'Tory rebellion over Covid laws set to be thwarted despite rising anger. Commons Speaker not expected to allow vote on amendment that would give MPs say on future laws',
#  'We can’t be squeamish about death. We need to confront our worst fears. Patients, their families and their doctors need to be open about the inevitable as the virus sweeps through our population',
#  'Less than 1% of Austrians infected with coronavirus, study shows. Research appears to scotch hopes of countries being close to relying on ‘herd immunity’',
#  "Future market for Covid vaccines 'could be worth more than $10bn a year'. Analysts estimate revenue generated, assuming an annual jab at an average price of $20",
#  'UK hospitals to trial five new drugs in search for coronavirus treatment. Exclusive: thirty hospitals looking to sign up hundreds of patients to take part in studies',
#  'The coronavirus infection rate is still too high. There will probably be a second wave | David Hunter. Test and tracing is launching today but it will need to be massively stepped up to have an impact, says David Hunter, professor of epidemiology at the University of Oxford',
#  'Non-woven masks better to stop Covid-19, says Japanese supercomputer. Disposable medical face masks beat those made of cotton or polyester in simulation',
#  'Scientists ask: could summer heat help beat Covid-19?. Experts are watching carefully to see if this virus will follow the seasonal pattern of flu, but warn that the difference may be minor',
#  'Scammers exploit Covid to steal from stressed bank customers. Criminals are adapting their tactics to take advantage of those spending more time at home and feeling vulnerable',
#  'Covid-19 reveals the alarming truth that many children can’t wash their hands at school | Laura McInerney. A survey found that 37% of teachers said they did not have hot water and soap available for pupils',
#  'People who are shielding: how do you feel about the new lockdown rules?. As restrictions ease for people who are not subject to health conditions, do you feel forgotten about, isolated or cut off?',
#  "Hospital chiefs 'increasingly frustrated' with UK testing failures. NHS Providers lambasts comprehensively missed target of 100,000 daily test as a ‘red herring’",
#  'Demand for flu vaccine soars as countries plan for second Covid-19 wave. Manufacturers warn they will struggle to meet demand as governments seek to ease pressure on health services',
#  'Pfizer Covid vaccine: what has the trial found and is this a breakthrough?. Early results from phase 3 trial look promising but there are still many questions to be answered<br>',
#  "I was so anxious I couldn't sit down': how a high street centre is helping people in crisis. Coronavirus and lockdown have taken a huge toll on people’s mental health. A Stockport drop-in shop is offering vital face-to-face support <br><br>",
#  'UK scientists want to infect volunteers with Covid-19 in race to find vaccine. Trials could be speeded up by using risky strategy of deliberately introducing the virus ',
#  'UK plans £250m boost for cycle lanes and fast-track e-scooter trials. Campaigners call for redesign of transport system to help prevent bounce-back in air pollution',
#  'Oldham may face full lockdown after Covid cases double. Sudden rise in infection rate means bars, restaurants and gyms might have to close again',
#  'Daily updates on English Covid-19 deaths paused amid accuracy concerns. Government confirms PHE set no cut-off between time of testing and date of death',
#  'Blood sample shortage holding up UK work on antibody tests. Not enough people yet known to have recovered from virus to provide sufficient blood',
#  "Social workers' efforts to protect children in lockdown have gone unnoticed | Harry Ferguson. As one of the only professions to continue doing home visits, social workers alone can not keep children safe from harm",
#  'Migrant healthcare staff still paying NHS fee despite Johnson U-turn. Many NHS workers charged £400 to use health service after PM said he would axe surcharge',
#  'Executive pay capped at private hospitals during NHS takeover. Government limits pay in return for state support as sector struggles for revenue during coronavirus crisis',
#  'Small firms hit by coronavirus could miss out on bounce-back loans. Concern over lack of lenders signing up for state scheme to offer low-cost emergency loans',
#  'Birmingham medics investigate high BAME Covid-19 death rate. One Birmingham hospital saw BAME communities make up 64% of coronavirus deaths',
#  'Coronavirus has exposed the dangerous failings of NHS marketisation | David McCoy. The coalition government’s 2012 act weakened the healthcare system’s ability to cope with a pandemic, says David McCoy, professor of global public health at Queen Mary University of London',
#  "Are coronavirus antibody tests worth the money? As a GP, I thought I'd give one a try | Ann Robinson. The commercial kits are tempting, but offer little certainty when we aren’t even sure that antibodies confer immunity, says GP Ann Robinson",
#  'Schools in England could close when teachers self-isolate. Leaders say it may not be possible for schools to remain open if there are too few staff',
#  'Out-of-work households £1,600 worse off during Covid-19 due to austerity. IFS says benefits for families hit by unemployment are worth at least 10% less than in 2011',
#  'Scientists raise concerns about quality of UK Covid-19 tests. Warning that infections could be missed amid questions about credibility of testing operation',
#  'UK has opted out of EU coronavirus vaccine programme, sources say. EU to invest €2bn on vaccines now being tested but UK officials say scheme benefits are ‘limited’',
#  'The Guardian view on the Covid-19 strategy: insuring against a killer. <strong>Editorial:</strong> A virus that could almost double the number of deaths a year in the UK was left to spread untracked and could have overwhelmed the NHS. That can’t be allowed to happen again',
#  'Calls for funds to house domestic violence victims during Covid-19 outbreak. Signs of surge in abuse and killings as women’s anti-violence groups call on government to do more',
#  'People who think they have had Covid-19 ‘less likely to download contact-tracing app’. Study’s findings highlight potential long-term damage of UK’s early testing strategy',
#  'UK experts fear up to 120,000 Covid-19 deaths this winter. Preparations to avoid second wave worst-case scenario in NHS hospitals ‘must start now’',
#  'Care homes in England say coronavirus death toll has risen to 1,400. Figure far outstrips official total of 217 as testing finally begins for staff and residents<br>',
#  'Test failures and lack of openness result from pro-private, anti-public ideology | Letters. Letters: <strong>Prof Nick Spence</strong><strong>r</strong> says the private outsourcing of health services is behind the failure of test and trace programmes, while <strong>Dr Ian Davis</strong> says the government should be recruiting staff to test for Covid-19 through the NHS',
#  'Isolation period for those with Covid symptoms may be increased to 10 days. Proposal comes as concern over second wave ‘very high’ in NHS',
#  'Why UK Covid testing must be more than just a numbers game. Focus should not be on how many tests are done, but how they are used and where, say experts',
#  'NHS coronavirus crisis volunteers frustrated at lack of tasks. Vast majority of 750,000 people who signed up to help are yet to be called into action',
#  'Nearly 1,500 JCB jobs at risk as demand for machines halves.  Digger maker says 500 agency workers to be laid off and 950 further staff under threat despite extension of Covid-19 furlough scheme ',
#  'For the Covid economic recovery look to the Treasury, not the Bank. Fears about high government borrowing raising inflation and interest rates are overstated',
#  "Words I thought I'd never write: thank God for Matt Hancock | John Crace. The health secretary wrote off £13bn of NHS debt, promised 100,000 tests and acted like a grownup",
#  "Royal Mail staff 'lack sufficient protection' from coronavirus. Communication Workers Union estimates half of sorting offices have insufficient PPE and sanitiser",
#  'Are breathing techniques good for your health?. The market is flooded with books and classes claiming ‘breathwork’ can help with mental health, sleep and even Covid-19. But experts are not convinced',
#  "UK blood couriers 'not given gloves and hand sanitiser' for Covid-19 samples. Self-employed couriers launching legal action over lack of sufficient personal protection equipment",
#  'Myths and realities of public sector pay hikes. <strong>Letters: </strong><strong>George Binette </strong>says less than a quarter of workers will benefit, while<strong> </strong><strong>Vic Rayner </strong>decries the fact that care home staff have been forgotten and <strong>Angela Pickering</strong> believes the headlines are just government spin. Plus <strong>Marc Boix Codony</strong>, a consultant neurologist, is clear where the money should go – and it’s not to him',
#  "Malaysian prisoners may face 'forced labour' on palm oil plantations. Shortage of foreign workers behind plan by producers to employ inmates as a stopgap measure"]

# %%
preds_politics = pd.read_csv("./models/preds_politics.csv", index_col=0)
# not bad but may be worth doing it in a different way or dropping the topic

# %%
preds_politics.nlargest(60, "pred_1")['title_subtitle'].tolist()
# Out:
# ['The Guardian view on Covid and the north-south divide: inequality kills | Editorial. <strong>Editorial: </strong>Boris Johnson won a landslide promising to ‘level up’ the UK. Yet the pandemic threatens to level down the country',
#  'We must not let the government seize back control from doctors | Andrew Lansley. Boris Johnson wants to restructure the NHS. But the lesson of Covid-19 is there is not too little central power, but too much, says former health secretary Andrew Lansley',
#  'Boris Johnson says four nations working on family Christmas plan. Prime minister concedes test-and-trace system ‘hasn’t had as much impact’ as desired',
#  'Bereaved relatives call for immediate inquiry into Covid-19 crisis. Lawyers for 450 people call on Boris Johnson to start public inquiry to help prevent deaths',
#  'As business bigwigs fight to end lockdown, the hero fending them off is … Boris Johnson? | Joel Golby. Tory donors and a few bored people may want the shops to reopen, but let’s not pack away the jigsaws yet, says author Joel Golby',
#  "With Raab at the reins, things are really getting finger-lickin' bad | John Crace. Left in charge of the UK’s front-of-house, the foreign secretary struggled with basic hygiene at the daily press briefing",
#  'Doctors to prescribe bike rides to tackle UK obesity crisis. Boris Johnson to announce new measures to make cycling safer and cheaper to improve health and cut virus risk<br>',
#  "‘After Boris Johnson’s Zoom call, all hell broke loose’: inside the world's favourite video app. Ten years ago, Silicon Valley had written off Zoom. Now it’s used by everyone from princes to piano teachers",
#  "If we follow Boris Johnson's advice, coronavirus will spread | David Hunter. A large-scale return to work without the ability to test, trace and isolate risks creating super-spreader events, says epidemiology professor David Hunter",
#  "Boris Johnson's education catch-up plans do not reflect reality. Experts fear it will be impossible to deliver on tutoring pledge for a million children by September",
#  "In 12 weeks we can turn the tide': now we can ask – was Boris Johnson right?. Coronavirus deaths and infections are dropping, but experts fear lockdown is being eased too soon",
#  'Boris Johnson promises ‘maximum caution’ in easing Covid-19 restrictions.  Downing Street pours cold water on reports lockdown could be lifted from Monday ',
#  "Keir Starmer accuses PM of placing parents in 'impossible position'. Labour leader condemned Boris Johnson’s call for employees to return to work without efficient childcare support",
#  'Matt Hancock sets target of 100,000 coronavirus tests a day. Health secretary ‘determined’ to reach six-figure goal for England by end of April',
#  'Boris Johnson to warn UK: tougher lockdown may be necessary. Outbreak will get worse before it gets better, PM tells nation as death toll hits 1,000',
#  'Boris Johnson urged to set out recovery plan for schools in England. Ministers warned country may face ‘educational poverty’ if no strategy in place for September',
#  'Former chancellor Alistair Darling calls for emergency VAT cut. Move to stimulate spending as part of Covid-19 recovery plan makes sense, says politician',
#  'Johnson promises plan next week for return to schools and work. PM says UK is past peak of coronavirus and vows to produce road map for economy',
#  'Science and politics: a complicated formula | Letters. Letters: <strong>Prof Ravi Mahajan</strong> and <strong>Alan Walker</strong> respond to Richard Horton’s article in which he questions how scientists can stand by this government. Plus <strong>Philip Barber </strong>wonders why we are being led by science, while simultaneously disregarding it',
#  'Bleak day for UK as Centrica, Johnson Matthey and Heathrow announce big job losses. British Gas to slash 5,000 jobs, Johnson Matthey, 2,500, as Heathrow Airport launches redundancy programme',
#  'PM tells Britons to avoid non-essential travel and contact. Boris Johnson announces series of new measures including 14-day isolation for households with symptoms',
#  'The Guardian view on the UK’s testing failure: much to learn from Germany | Editorial. <strong>Editorial:</strong> Matt Hancock says our European rival did better because of its industrial strengths. But it also benefited from its political ones',
#  'Black Lives Matter protests risk spreading Covid-19, says Hancock. Health secretary denies UK is racist, and repeats calls to keep to distancing rules at rallies',
#  'To get people to use face masks, we need solidarity, not shaming | Frances Ryan. To tackle coronavirus in England, Boris Johnson should commit to teaching not just the science but the ethics behind the rules, says Guardian columnist Frances Ryan',
#  'Matt Hancock: England in good position to avoid major Covid resurgence. Health secretary hails weekly mass testing programme but admits he is ‘very worried’ about surge in cases',
#  "Covid can change UK like 'new Jerusalem' of 1940s, Johnson claims. Prime minister tells virtual Tory conference that country must not return to status quo",
#  "Germany's Covid-19 expert: 'For many, I'm the evil guy crippling the economy'. Germany’s leading coronavirus expert Christian Drosten on Merkel’s leadership, the UK response and the ‘prevention paradox’Coronavirus – latest updatesSee all our coronavirus coverage",
#  'Coronavirus: Boris Johnson to hold Cobra meeting as UK death toll hits three. Prime minister to consider bringing in tougher measures to delay spread of outbreak',
#  'Matt Hancock says he backs any police action against Neil Ferguson. Met says scientist will face no further action after UK health secretary says lockdown breach leaves him speechless',
#  'Typhoid Dido proves fluent in management bollocks and contradiction | John Crace. Harding has the appearance of someone prepared to put the hours in, even if they aren’t put to much obvious use',
#  'The coronavirus and an overstretched NHS | Letters. <strong>Letters:</strong> There will be no Dad’s Army-style workforce of retired doctors as the government claims, writes <strong>Dr Pete Ford, </strong>while <strong>Dr Brigid Purcell</strong> says the health system is already struggling to cope after a decade of cuts. Plus letters from <strong>Judith Kent</strong>, <strong>Steve Flatley</strong>, <strong>Martin Angell</strong> and <strong>Michael Cunningham</strong>',
#  "It's not just Neil Ferguson – scientists are being attacked for telling the truth | Bob Ward. The media vilification of the government adviser is about far more than social distancing, says policy director Bob Ward",
#  "What does ‘national defence' mean in a pandemic? It's no time to buy fighter jets | George Monbiot. The UK dismissed early warnings about coronavirus – spending billions on the arms industry while ignoring real threats, says Guardian columnist George Monbiot",
#  "Contact apps won't end lockdown. But they might kill off democracy | John Naughton. A tech solution to the crisis of the type being pursed by the UK government will be both ineffective and a civil rights nightmare",
#  'Coronavirus has killed 30,000 Americans, and all Trump can do is blame the WHO. The US president is scapegoating the health organisation to mask his own deadly inaction, says public health professor Martin McKee',
#  'EU turns up pressure on Matt Hancock over Covid-19 PPE scheme. Brussels says UK was briefed on bulk-buying plan and given ‘ample opportunity’ to join',
#  'Testing efforts led by ex-lobbyist who backed Hancock leadership bid. Lord Bethell, who gave money to Hancock’s failed campaign to be Tory leader, is understood to be ‘lead minister’ for testing',
#  'Matt Hancock accused of blaming public for Covid test shortages. UK health secretary claims a quarter of people coming forward for checks are ineligible',
#  "Boris Johnson pinning hopes on £100bn 'moonshot' to avoid second lockdown.  PM believes huge rapid testing programme is ‘only hope’ before a vaccine, leaked document says ",
#  'Macron expected to ask UK to review 14-day quarantine rule. The French president visits No 10 for talks on Thursday during trip to commemorate WWII alliance',
#  'Rishi Sunak heeds calls to help charities with £750m extra funding. UK chancellor concedes move will not save all charities from collapse during coronavirus crisis ',
#  'Grant Shapps discusses rescue package with UK airlines. Sources make clear any assistance will be conditional on ensuring critical routes remain open',
#  "Hancock's shiny badge? Emblem of a scamper into Tigger mode | John Crace.  Health secretary puts plenty of bounce into Care badge but bunks off over virus test queries at Q&amp;As ",
#  'UK has reached peak of coronavirus outbreak, says Matt Hancock. Health secretary tells MPs social distancing is working but lockdown will remain',
#  'Test failures and lack of openness result from pro-private, anti-public ideology | Letters. Letters: <strong>Prof Nick Spence</strong><strong>r</strong> says the private outsourcing of health services is behind the failure of test and trace programmes, while <strong>Dr Ian Davis</strong> says the government should be recruiting staff to test for Covid-19 through the NHS',
#  "The WHO v coronavirus: why it can't handle the pandemic. <strong>The long read</strong>: Attacked by Trump and ignored by many of its most powerful members, the World Health Organization is facing a major crisis – just at the moment we need it most",
#  'Chancellor set to announce £3bn green investment package. Campaigners say Rishi Sunak’s plan to decarbonise public buildings does not go far enough ',
#  'UK treasury minister calls for return to work to help economy recover from coronavirus. Steve Barclay issues plea to employers amid words of caution from unions and industry body',
#  "MPs call for 'virtual Commons' amid Covid-19 early recess. Lib Dem’s Ed Davey said UK should create select committee on coronavirus",
#  'Matt Hancock orders urgent review of PHE Covid-19 death figures. Move comes after it emerges statistics may include people who died of other causes',
#  'Ted Baker founder cuts stake by 55% in emergency funding bid. Ray Kelvin hands control of fashion retailer to investor known as ‘the Rottweiler’',
#  'Coronavirus: ‘rule of six’ to apply in England from Monday.  Boris Johnson restricts gatherings in attempt to prevent second national lockdown ',
#  'Coronavirus has exposed a desperate need for localism | Simon Jenkins. A new Beveridge-style report on the welfare of communities could help our traumatised minds focus on the future, says Guardian columnist Simon Jenkins',
#  'Care home crisis is the result of years of neglect | Letters. Letters: <strong>Bill Shaw</strong> says the Thatcher government systematically dismantled social care provision, while <strong>Les Bright </strong>highlights what went wrong with private services. Plus letters from <strong>Tom Wilson</strong> and <strong>J</strong><strong>anet Broadmore</strong>',
#  'Coronavirus test delays ‘could jeopardise UK tracing system’. Ex-health secretary Jeremy Hunt issues warning as Sage committee assesses scheme<br>',
#  'The Guardian view on the danger for the arts: action is needed now | Editorial. <strong>Editorial: </strong>After three months of silence, Oliver Dowden must do more than issue vague reassurances',
#  'Myths and realities of public sector pay hikes. <strong>Letters: </strong><strong>George Binette </strong>says less than a quarter of workers will benefit, while<strong> </strong><strong>Vic Rayner </strong>decries the fact that care home staff have been forgotten and <strong>Angela Pickering</strong> believes the headlines are just government spin. Plus <strong>Marc Boix Codony</strong>, a consultant neurologist, is clear where the money should go – and it’s not to him',
#  "This is so wrong': Hollande highlights domestic violence in French lockdown. Ex-president backs new app for victims as WHO reports 60% rise in domestic abuse calls",
#  'JD Wetherspoon plans to reopen pubs in June. After Tim Martin’s scepticism over lockdown, chief executive delivers upbeat message to investors',
#  "Since when did teacher-shaming become Britain's national sport? | Shami Chakrabarti. They’re accused of ‘scaremongering’ over the reopening of schools. But we can’t let classrooms reignite coronavirus, says Labour peer Shami Chakrabarti"]

# %%
preds_social_issues = pd.read_csv("./models/preds_social_issues.csv", index_col=0)
# so-so

# %%
preds_social_issues.nlargest(60, "pred_1")['title_subtitle'].tolist()
# Out:
# ['It is time we made masks compulsory | Letters. <strong>Letters: </strong>Countries where face mask use is widespread have seen fewer Covid-19 deaths, writes <strong>Prof David Smith</strong>, while <strong>Philip Rundall</strong> thinks shops should do more to encourage customers to wear them',
#  'Care home crisis is the result of years of neglect | Letters. Letters: <strong>Bill Shaw</strong> says the Thatcher government systematically dismantled social care provision, while <strong>Les Bright </strong>highlights what went wrong with private services. Plus letters from <strong>Tom Wilson</strong> and <strong>J</strong><strong>anet Broadmore</strong>',
#  'Universities have let their students down | Letters. <strong>Letters: </strong>Current difficulties were predictable and avoidable, writes <strong>one academic</strong>, while <strong>Maria Gajewska </strong>wonders when a fee refund might be due. Meanwhile, <strong>William Proctor </strong>believes it is the government, not institutions, that bears responsibility for the crisis ',
#  'Why few Britons pick fruit on our farm | Letter. <strong>Letters: </strong>For distancing reasons we are minimising the number of people on the campsite so only have room for those who have worked for us before, but we are keen to recruit local people and have been in touch with many, writes <strong>Andrew Chesson</strong>',
#  'No room for complacency over Covid death toll | Letters. Letters:<strong> </strong><strong>Prof Steve Tombs </strong>on how changing the criteria for recording deaths has skewed the data, and <strong>Richard Post </strong>on the trouble with tracking deaths against cases ',
#  'In lockdown, parents are mastering the art of the meme. What could go wrong? | Eleanor Margolis. Who thought the family WhatsApp group would alleviate our existential dread? We’re in strange times, says Eleanor Margolis ',
#  'Johnson shows again he can get away with stuff other PMs couldn’t. For a leader to holiday while floods hit the country isn’t normal, but ours believes in his own exceptionalism',
#  'The Guardian view on plans for primary schools: stop bullying teachers | Editorial. <strong>Editorial: </strong>Staff and unions are right to demand information from ministers. Attacking them undermines the government’s case']

# %%
preds_travel_lockdown = pd.read_csv("./models/preds_travel_lockdown.csv", index_col=0)
# good but it's mostly just picking the word lockdown

# %%
preds_travel_lockdown.nlargest(60, "pred_1")['title_subtitle'].tolist()
# Out:
# ["Police call for end to 'lockdown-shaming' as a weapon in feuds. Forces receiving thousands of complaints about rule-breaking, fear many are being used to settle scores",
#  'Flexible working will be norm after lockdown, say Barclays and WPP bosses. Crowded office buildings ‘may be a thing of the past’ as staff safety prioritised after Covid-19 crisis',
#  'Chancellor extends UK furlough scheme until end of October. Rishi Sunak says programme will run for further four months as Britain exits lockdown',
#  'Low demand for power causes problems for National Grid. Energy system operator says lower usage during lockdown could put network under stress',
#  'As UK lockdowns ease, fears grow of return to pre-pandemic crime and pollution levels. Carbon emissions, crime and air pollution all fell but are now starting to rebound',
#  'Sales of alcohol, tea and coffee soar in shops since UK lockdown.  Consumers continue to largely eat and drink at home even as Covid-19 lockdown loosens ',
#  "UK police receive 194,000 calls from lockdown 'snitches'. Police chiefs says people finding it harder to observe measures the longer they go on",
#  'Ikea to reopen 19 stores during UK lockdown.  Britain’s biggest furniture chain installs Covid-19 safety measures for 1 June reopening ',
#  'Rishi Sunak preparing to wind down coronavirus furlough scheme from July. UK chancellor set to scale back job retention measure as coronavirus lockdown eases',
#  "Spain's streets turn eerily quiet following coronavirus lockdown. Transformation of usually bustling Madrid and Barcelona spooks the few residents and tourists to venture out",
#  'Coronavirus: Foreign Office finalising plans to evacuate Britons. FCO urgently exploring options for British nationals to leave Hubei province, says No 10',
#  'Record numbers used UK food banks in first month of lockdown.  Charities say government support is failing to protect low-income families',
#  "Lockdown means energy bills will rise. Here's how to keep costs down. There are still many ways to save money though millions of us are mostly stuck indoors",
#  '950,000 apply for universal credit in two weeks of UK lockdown. The government has moved 10,000 staff to process claims and is recruiting more',
#  "Boris Johnson's speech in full: 'first, careful steps' to ease Covid-19 lockdown. Read the full text of the UK prime minister’s address to the nation on Sunday 10 May",
#  "Stephen Timms: 'Universal credit's five-week delay is indefensible'. As work and pensions committee publishes new report, its chair says ‘needlessly punitive’ sanctions must be junked after lockdown ",
#  'Coronavirus: a dozen UK schools send pupils home after Italy trips. Schoolchildren told to self-quarantine for 14 days as precaution',
#  'Donations to be quarantined as UK charity shops plan to reopen. Charities have been badly hit by lockdown, with some reporting millions of pounds a month lost as result of shops being shut',
#  'Labour calls for end to migrant benefit block during lockdown. Shadow immigration minister seeks change to rules that deny access to public funds',
#  "Arts Council England promises £160m to 'buoy public' during lockdown. Funding announced to protect arts bodies and freelancers as coronavirus hits revenues",
#  'Isolating students offered food, toiletries but no financial support by UK universities. UUK produces ‘care checklist’ but critics say it has come too late for many in lockdown',
#  'Climate crisis: in coronavirus lockdown, nature bounces back – but for how long?.  While carbon emissions fall as human activity decreases, in the end it will be about the politics <br>',
#  '10 of the UK’s best spring walks. Pubs and restaurants may be closed and dark, but all over the UK wildlife is bursting into the light of longer days and it’s never been more important to get some fresh air. Nature writers select their favourite seasonal destinations',
#  'High street gloom eases as UK shops report brisker trade. Retailers report best sales in more than a year after the easing of lockdown restrictions',
#  'Bank of England to finance UK government Covid-19 crisis spending. With lockdown likely to be extended Treasury can draw on billions in extra funds to support cashflow',
#  'Half of exam-year UK pupils given no school work since March, finds study. Students who missed out on six months of education due to lockdown will fall behind, fear report’s authors',
#  "Link climate pledges to €26bn airline bailout, say Europe's greens. Environment groups insist conditions must be attached to Covid-19 rescue plan for sector<br>",
#  'V&A dishes up a fried breakfast dress for first lockdown design day. Dame Edna Everage’s wacky gown takes centre stage in online activity day for children<br>',
#  "Contact apps won't end lockdown. But they might kill off democracy | John Naughton. A tech solution to the crisis of the type being pursed by the UK government will be both ineffective and a civil rights nightmare",
#  'Three who fled quarantine on UK farm found and self-isolating. Police had searched for the trio, one of whom had tested positive for Covid-19, since Monday',
#  'UK creative industries facing £74bn drop in income after lockdown. Report says 400,000 jobs likely to be lost across sectors including music, theatre and art',
#  'UK plans £250m boost for cycle lanes and fast-track e-scooter trials. Campaigners call for redesign of transport system to help prevent bounce-back in air pollution',
#  "Easter is a time to connect. So even in isolation, let's cherish the ties that bind. During the lockdown, we’ve discovered that what truly matters is empathy and kindness and collaboration",
#  'UK presses China to let dual nationals join coronavirus exodus. China does not recognise dual nationality and is not letting Chinese passport holders leave',
#  '‘I can’t afford to turn away business’: view from shops on face mask rules.  The Guardian speaks to shop owners about new face mask rules in Scotland and England ']

# %%
preds_treatments_vaccines = pd.read_csv("./models/preds_treatments_vaccines.csv", index_col=0)
# not very good

# %%
preds_treatments_vaccines.nlargest(60, "pred_1")['title_subtitle'].tolist()
# Out:
# ['Why does Covid-19 affect ethnic minorities so badly? It isn’t to do with biology | Zubaida Haque. All the evidence points to race inequality as an urgent aspect of the epidemic, but the government refuses to act, says Zubaida Haque of the Runnymede Trust',
#  'After coronavirus, focus on the climate emergency | Letters. <strong>Letters: </strong>Signatories including <strong>Dr Wolfgang Knorr</strong><strong> </strong>say it is game over for preventing dangerous climate change, <strong>Colin Hines</strong> says a green infrastructure should be prioritised in a post-Covid-19 world, and <strong>Andy Radford</strong> on why we should consider permanent changes to the way we live ',
#  'Myths and realities of public sector pay hikes. <strong>Letters: </strong><strong>George Binette </strong>says less than a quarter of workers will benefit, while<strong> </strong><strong>Vic Rayner </strong>decries the fact that care home staff have been forgotten and <strong>Angela Pickering</strong> believes the headlines are just government spin. Plus <strong>Marc Boix Codony</strong>, a consultant neurologist, is clear where the money should go – and it’s not to him',
#  "Isolation and contemplation: Nadav Kander's visual response to coronavirus. In the first part of our series commissioned in conjunction with the Prix Pictet, a global award in photography and sustainability, photographers who have won or been shortlisted for the award over the last decade have been asked to make a personal response to the Covid-19 crisis. Here <strong>Nadav Kander</strong> speaks about his submission Solitude - Quietude – Contemplation",
#  'Call for volunteers to help elderly in coronavirus crisis. Welsh authorities plan to recruit ‘army’ of non-qualified people, while local support groups are self-organising across the UK<br /><br />• <a href="https://www.theguardian.com/world/live/2020/mar/14/coronavirus-live-updates-uk-us-australia-italy-europe-school-shutdown-sport-events-cancelled-latest-update-news" title="">Coronavirus latest updates</a><br />• <a href="https://www.theguardian.com/world/live/2020/mar/14/coronavirus-live-updates-uk-us-australia-italy-europe-school-shutdown-sport-events-cancelled-latest-update-news" title="">See all our coronavirus coverage</a>',
#  'Winning by a nose: the dogs being trained to detect signs of Covid-19. In the battle against the virus, we have an unlikely ally. Already used to detect drugs and weapons, dogs are now being trained to sniff out when humans have the virus. Tim Lewis meets the trainers and their hounds',
#  "There is a world beyond lockdown. It's time to come up with a hopeful vision | James Meadway. We have to confront reality, but it need not be bleak. Where is the radical thinking about a pandemic-proof Britain, asks James Meadway, associate fellow of the IPPR",
#  'I’m an ICU doctor. The NHS isn’t ready for the coronavirus crisis | Tim Cook. As the virus spreads quickly in the UK, hospitals need to step up plans to care for the very sick, recruit more staff and cancel routine surgery, says ICU doctor Tim Cook',
#  'The coronavirus and an overstretched NHS | Letters. <strong>Letters:</strong> There will be no Dad’s Army-style workforce of retired doctors as the government claims, writes <strong>Dr Pete Ford, </strong>while <strong>Dr Brigid Purcell</strong> says the health system is already struggling to cope after a decade of cuts. Plus letters from <strong>Judith Kent</strong>, <strong>Steve Flatley</strong>, <strong>Martin Angell</strong> and <strong>Michael Cunningham</strong>',
#  'Test failures and lack of openness result from pro-private, anti-public ideology | Letters. Letters: <strong>Prof Nick Spence</strong><strong>r</strong> says the private outsourcing of health services is behind the failure of test and trace programmes, while <strong>Dr Ian Davis</strong> says the government should be recruiting staff to test for Covid-19 through the NHS',
#  'Cholera and coronavirus: why we must not repeat the same mistakes. <strong>The long read</strong>: Cholera has largely been beaten in the west, but it still kills tens of thousands of people in poorer countries every year. As we search for a cure for coronavirus, we have to make sure it will be available to all, not just to those in wealthy nations',
#  "Antibody tests aren't perfect, but they may be Britain's way out of the lockdown | Eleanor Riley. They can show false negatives and positives, but the tests could help us track the spread of the virus, says professor of immunology Eleanor Riley",
#  'Science and politics: a complicated formula | Letters. Letters: <strong>Prof Ravi Mahajan</strong> and <strong>Alan Walker</strong> respond to Richard Horton’s article in which he questions how scientists can stand by this government. Plus <strong>Philip Barber </strong>wonders why we are being led by science, while simultaneously disregarding it',
#  "We found the first cat in the UK with Covid-19 - but there's no need to panic | Willie Weir. The feline had caught coronavirus from its owners, but our research shows it’s a rare occurrence, says Willie Weir,<strong> </strong>professor of veterinary infectious disease",
#  'Covid-19 makes it clearer than ever: access to the internet should be a universal right | Tim Berners-Lee. The internet eased lockdown life for millions. But millions more still can’t get online, and that’s fundamentally unfair, says web inventor Tim Berners-Lee ',
